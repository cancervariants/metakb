# %% [markdown]
# # Create GKS object for genes in cBioportal transformer

# %% [markdown]
# This is a result of issue #547 in cancervariants/metakb repo

# %%
from os import environ

environ["AWS_ACCESS_KEY_ID"]="dummy"
environ["AWS_SECRET_ACCESS_KEY"]="dummy"
environ["AWS_SESSION_TOKEN"]="dummy"
environ["SEQREPO_ROOT_DIR"]="/usr/local/share/seqrepo/2024-12-20"

import metakb.harvesters.cbioportal as cbph
import metakb.transformers.cbp_es_dfarber_broad_2014 as cbpt
from metakb.transformers.base import Transformer

import pandas as pd
import requests
from tqdm import tqdm
from typing import List

import logging
_logger = logging.getLogger(__name__)

from ga4gh.core.models import (
    Coding,
    ConceptMapping,
    Extension,
    MappableConcept,
    Relation,
)
# Out:
# 200
# Downloaded es_dfarber_broad_2014.tar.gz
# Extracted to: es_dfarber_broad_2014_extracted

# %% [markdown]
# ## Import the CBP harvester and transformers
# Commment out this section after the first run to save time

# %%
#Run while inside the harvesters directory
f = cbph.cBioportalHarvester()
data = f.harvest()
g = cbpt.cBioportalTransformer()
df = g.transform(data)
# Out:
# Number of duplicate rows : 495
#
# Duplicate rows (excluding first instance):
#       Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 720         ABCA1          9       107607765     107607765
# 730         ABCA3         16         2338066       2338066
# 783         ABCC9         12        21954066      21954066
# 813         ACACA         17        35640173      35640173
# 829          ACHE          7       100490251     100490251
# ...           ...        ...             ...           ...
# 15134       STAG2          X       123179197     123179197
# 15155     ZDHHC15          X        74742823      74742824
# 15191       HUWE1          X        53579734      53579734
# 15216     SHROOM4          X        50350700      50350700
# 15218        SOX3          X       139586714     139586714
#
#               Consequence Variant_Classification Variant_Type  \
# 720      missense_variant      Missense_Mutation          SNP
# 730      missense_variant      Missense_Mutation          SNP
# 783      missense_variant      Missense_Mutation          SNP
# 813      missense_variant      Missense_Mutation          SNP
# 829    synonymous_variant                 Silent          SNP
# ...                   ...                    ...          ...
# 15134         stop_gained      Nonsense_Mutation          SNP
# 15155  frameshift_variant        Frame_Shift_Ins          INS
# 15191    missense_variant      Missense_Mutation          SNP
# 15216    missense_variant      Missense_Mutation          SNP
# 15218    missense_variant      Missense_Mutation          SNP
#
#       Reference_Allele Tumor_Seq_Allele2   SAMPLE_ID Sequence_Source  \
# 720                  G                 A  SJDES003-R             WXS
# 730                  C                 T  SJDES011-R             WXS
# 783                  C                 T    SJDES017             WXS
# 813                  T                 C    SJDES005             WXS
# 829                  G                 A     03-P152             WXS
# ...                ...               ...         ...             ...
# 15134                C                 T    SJDES006             WXS
# 15155                -                 C    SJDES010             WXS
# 15191                C                 A      TTC466             WXS
# 15216                C                 T      TTC466             WXS
# 15218                T                 C      TTC466             WXS
#
#                              HGVSc              HGVSp  HGVSp_Short  \
# 720     ENST00000374736.3:c.806C>T        p.Ala269Val      p.A269V
# 730    ENST00000301732.5:c.2965G>A        p.Ala989Thr      p.A989T
# 783    ENST00000261200.4:c.4562G>A       p.Arg1521Gln     p.R1521Q
# 813     ENST00000353139.5:c.605A>G        p.Asn202Ser      p.N202S
# 829    ENST00000302913.4:c.1257C>T          p.Pro419=      p.P419=
# ...                            ...                ...          ...
# 15134   ENST00000218089.9:c.646C>T        p.Arg216Ter      p.R216*
# 15155    ENST00000373367.3:c.36dup  p.Leu13AlafsTer30  p.L13Afs*30
# 15191  ENST00000342160.3:c.8615G>T       p.Gly2872Val     p.G2872V
# 15216  ENST00000376020.2:c.3442G>A       p.Glu1148Lys     p.E1148K
# 15218   ENST00000370536.2:c.512A>G        p.Lys171Arg      p.K171R
#
#          Transcript_ID          RefSeq  Protein_position
# 720    ENST00000374736     NM_005502.3             269.0
# 730    ENST00000301732     NM_001089.2             989.0
# 783    ENST00000261200     NM_020297.2            1521.0
# 813    ENST00000353139     NM_198834.1             202.0
# 829    ENST00000302913     NM_015831.2             419.0
# ...                ...             ...               ...
# 15134  ENST00000218089  NM_001042749.1             216.0
# 15155  ENST00000373367     NM_144969.2              12.0
# 15191  ENST00000342160             NaN            2872.0
# 15216  ENST00000376020     NM_020717.3            1148.0
# 15218  ENST00000370536     NM_005634.2             171.0
#
# [495 rows x 17 columns]
#
# DataFrame shape after removing duplicates: (14737, 17)
# Number of duplicate rows : 0
# No duplicate rows found.
# Number of duplicate rows : 0
# No duplicate rows found.
# Number of duplicate rows : 0
# No duplicate rows found.
# Original shape: (14737, 27)
# Removed 3123 rows where SAMPLE_CLASS == 'Cell line'
# New shape: (11614, 27)
# Total variants in list: 53
# ▶️ Checking variant: 23-70824012-C-T
# ❌ Failed to parse JSON for: X-70824012-C-T
# ❌ Failed to parse JSON for: Y-70824012-C-T
# ▶️ Checking variant: 23-84258927-C-T
# ❌ Failed to parse JSON for: X-84258927-C-T
# ❌ Failed to parse JSON for: Y-84258927-C-T
# ▶️ Checking variant: 23-153184693-C-T
# ❌ Failed to parse JSON for: X-153184693-C-T
# ❌ Failed to parse JSON for: Y-153184693-C-T
# ▶️ Checking variant: 23-153175777-G-A
# ❌ Failed to parse JSON for: X-153175777-G-A
# ❌ Failed to parse JSON for: Y-153175777-G-A
# ▶️ Checking variant: 23-135772859-A-C
# ❌ Failed to parse JSON for: X-135772859-A-C
# ❌ Failed to parse JSON for: Y-135772859-A-C
# ▶️ Checking variant: 23-135827412-A-G
# ❌ Failed to parse JSON for: X-135827412-A-G
# ❌ Failed to parse JSON for: Y-135827412-A-G
# ▶️ Checking variant: 23-18192265-T-A
# ❌ Failed to parse JSON for: X-18192265-T-A
# ❌ Failed to parse JSON for: Y-18192265-T-A
# ▶️ Checking variant: 23-15552431-G-A
# ❌ Failed to parse JSON for: X-15552431-G-A
# ❌ Failed to parse JSON for: Y-15552431-G-A
# ▶️ Checking variant: 23-1428413-C-T
# ❌ Failed to parse JSON for: X-1428413-C-T
# ❌ Failed to parse JSON for: Y-1428413-C-T
# ▶️ Checking variant: 23-32519921-C-T
# ❌ Failed to parse JSON for: X-32519921-C-T
# ❌ Failed to parse JSON for: Y-32519921-C-T
# ▶️ Checking variant: 23-71428259-A-G
# ❌ Failed to parse JSON for: X-71428259-A-G
# ❌ Failed to parse JSON for: Y-71428259-A-G
# ▶️ Checking variant: 23-70444064-C-T
# ❌ Failed to parse JSON for: X-70444064-C-T
# ❌ Failed to parse JSON for: Y-70444064-C-T
# ▶️ Checking variant: 23-108718554-T-C
# ❌ Failed to parse JSON for: X-108718554-T-C
# ❌ Failed to parse JSON for: Y-108718554-T-C
# ▶️ Checking variant: 23-152734633-G-C
# ❌ Failed to parse JSON for: X-152734633-G-C
# ❌ Failed to parse JSON for: Y-152734633-G-C
# ▶️ Checking variant: 23-153223671-C-T
# ❌ Failed to parse JSON for: X-153223671-C-T
# ❌ Failed to parse JSON for: Y-153223671-C-T
# ▶️ Checking variant: 23-53575184-C-T
# ❌ Failed to parse JSON for: X-53575184-C-T
# ❌ Failed to parse JSON for: Y-53575184-C-T
# ▶️ Checking variant: 23-53247029-G-A
# ❌ Failed to parse JSON for: X-53247029-G-A
# ❌ Failed to parse JSON for: Y-53247029-G-A
# ▶️ Checking variant: 23-30268970-A-G
# ❌ Failed to parse JSON for: X-30268970-A-G
# ❌ Failed to parse JSON for: Y-30268970-A-G
# ▶️ Checking variant: 23-30237495-T-C
# ❌ Failed to parse JSON for: X-30237495-T-C
# ❌ Failed to parse JSON for: Y-30237495-T-C
# ▶️ Checking variant: 23-30237111-G-A
# ❌ Failed to parse JSON for: X-30237111-G-A
# ❌ Failed to parse JSON for: Y-30237111-G-A
# ▶️ Checking variant: 23-19391803-G-A
# ❌ Failed to parse JSON for: X-19391803-G-A
# ❌ Failed to parse JSON for: Y-19391803-G-A
# ▶️ Checking variant: 23-70357689-C-T
# ❌ Failed to parse JSON for: X-70357689-C-T
# ❌ Failed to parse JSON for: Y-70357689-C-T
# ▶️ Checking variant: 23-106186330-C-T
# ❌ Failed to parse JSON for: X-106186330-C-T
# ❌ Failed to parse JSON for: Y-106186330-C-T
# ▶️ Checking variant: 23-118725211-A-G
# ❌ Failed to parse JSON for: X-118725211-A-G
# ❌ Failed to parse JSON for: Y-118725211-A-G
# ▶️ Checking variant: 23-46918083-T-C
# ❌ Failed to parse JSON for: X-46918083-T-C
# ❌ Failed to parse JSON for: Y-46918083-T-C
# ▶️ Checking variant: 23-152160017-G-C
# ❌ Failed to parse JSON for: X-152160017-G-C
# ❌ Failed to parse JSON for: Y-152160017-G-C
# ▶️ Checking variant: 23-47030516-C-T
# ❌ Failed to parse JSON for: X-47030516-C-T
# ❌ Failed to parse JSON for: Y-47030516-C-T
# ▶️ Checking variant: 23-153209091-G-A
# ❌ Failed to parse JSON for: X-153209091-G-A
# ❌ Failed to parse JSON for: Y-153209091-G-A
# ▶️ Checking variant: 23-109697532-A-G
# ❌ Failed to parse JSON for: X-109697532-A-G
# ❌ Failed to parse JSON for: Y-109697532-A-G
# ▶️ Checking variant: 23-106144104-G-A
# ❌ Failed to parse JSON for: X-106144104-G-A
# ❌ Failed to parse JSON for: Y-106144104-G-A
# ▶️ Checking variant: 23-73740919-C-T
# ❌ Failed to parse JSON for: X-73740919-C-T
# ❌ Failed to parse JSON for: Y-73740919-C-T
# ▶️ Checking variant: 23-129499602-C-T
# ❌ Failed to parse JSON for: X-129499602-C-T
# ❌ Failed to parse JSON for: Y-129499602-C-T
# ▶️ Checking variant: 23-135104837-A-G
# ❌ Failed to parse JSON for: X-135104837-A-G
# ❌ Failed to parse JSON for: Y-135104837-A-G
# ▶️ Checking variant: 23-21995227-C-T
# ❌ Failed to parse JSON for: X-21995227-C-T
# ❌ Failed to parse JSON for: Y-21995227-C-T
# ▶️ Checking variant: 23-155003998-C-T
# ❌ Failed to parse JSON for: X-155003998-C-T
# ❌ Failed to parse JSON for: Y-155003998-C-T
# ▶️ Checking variant: 23-48116682-C-T
# ❌ Failed to parse JSON for: X-48116682-C-T
# ❌ Failed to parse JSON for: Y-48116682-C-T
# ▶️ Checking variant: 23-30849637-G-A
# ❌ Failed to parse JSON for: X-30849637-G-A
# ❌ Failed to parse JSON for: Y-30849637-G-A
# ▶️ Checking variant: 23-79286496-T-C
# ❌ Failed to parse JSON for: X-79286496-T-C
# ❌ Failed to parse JSON for: Y-79286496-T-C
# ▶️ Checking variant: 23-101395767-C-T
# ❌ Failed to parse JSON for: X-101395767-C-T
# ❌ Failed to parse JSON for: Y-101395767-C-T
# ▶️ Checking variant: 23-107018344-C-T
# ❌ Failed to parse JSON for: X-107018344-C-T
# ❌ Failed to parse JSON for: Y-107018344-C-T
# ▶️ Checking variant: 23-53115005-C-T
# ❌ Failed to parse JSON for: X-53115005-C-T
# ❌ Failed to parse JSON for: Y-53115005-C-T
# ▶️ Checking variant: 23-47104792-C-T
# ❌ Failed to parse JSON for: X-47104792-C-T
# ❌ Failed to parse JSON for: Y-47104792-C-T
# ▶️ Checking variant: 23-40990737-G-A
# ❌ Failed to parse JSON for: X-40990737-G-A
# ❌ Failed to parse JSON for: Y-40990737-G-A
# ▶️ Checking variant: 23-155171659-A-C
# ❌ Failed to parse JSON for: X-155171659-A-C
# ❌ Failed to parse JSON for: Y-155171659-A-C
# ▶️ Checking variant: 23-7812030-C-T
# ❌ Failed to parse JSON for: X-7812030-C-T
# ❌ Failed to parse JSON for: Y-7812030-C-T
# ▶️ Checking variant: 23-8434397-C-T
# ❌ Failed to parse JSON for: X-8434397-C-T
# ❌ Failed to parse JSON for: Y-8434397-C-T
# ▶️ Checking variant: 23-10096159-C-T
# ❌ Failed to parse JSON for: X-10096159-C-T
# ❌ Failed to parse JSON for: Y-10096159-C-T
# ▶️ Checking variant: 23-128876154-C-T
# ❌ Failed to parse JSON for: X-128876154-C-T
# ❌ Failed to parse JSON for: Y-128876154-C-T
# ▶️ Checking variant: 23-2408485-G-C
# ❌ Failed to parse JSON for: X-2408485-G-C
# ❌ Failed to parse JSON for: Y-2408485-G-C
# ▶️ Checking variant: 23-101138860-T-C
# ❌ Failed to parse JSON for: X-101138860-T-C
# ❌ Failed to parse JSON for: Y-101138860-T-C
# ▶️ Checking variant: 23-152089287-G-A
# ❌ Failed to parse JSON for: X-152089287-G-A
# ❌ Failed to parse JSON for: Y-152089287-G-A
# ▶️ Checking variant: 23-129370462-G-A
# ❌ Failed to parse JSON for: X-129370462-G-A
# ❌ Failed to parse JSON for: Y-129370462-G-A
# ▶️ Checking variant: 23-134494503-C-T
# ❌ Failed to parse JSON for: X-134494503-C-T
# ❌ Failed to parse JSON for: Y-134494503-C-T
# Chr23_X
# False    11614
# Name: count, dtype: int64
# Chr23_Y
# False    11614
# Name: count, dtype: int64
# ⚠️ Found 53 row(s) with ambiguous chromosome identification.
#      temp_Gnomad_Notation Hugo_Symbol ambig_chrom
# 841       23-70824012-C-T        ACRC     neither
# 1297      23-84258927-C-T       APOOL     neither
# 1338     23-153184693-C-T     ARHGAP4     neither
# 1339     23-153175777-G-A     ARHGAP4     neither
# 1365     23-135772859-A-C     ARHGEF6     neither
# ambig_chrom
# non-ambiguous    11561
# neither             53
# Name: count, dtype: int64
# ❌ Row 841: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 841: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 1297: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 1297: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 1338: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 1338: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 1339: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 1339: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 1365: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 1365: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 1366: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 1366: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 1675: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 1675: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 1719: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 1719: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 2906: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 2906: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 3262: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 3262: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 3756: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 3756: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 4386: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 4386: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 4653: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 4653: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 4678: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 4678: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 4682: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 4682: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 4929: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 4929: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 5386: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 5386: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 5987: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 5987: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 5988: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 5988: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 5989: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 5989: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 6042: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 6042: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 6172: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 6172: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 6346: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 6346: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 6805: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 6805: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 7589: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 7589: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 7854: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 7854: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 8397: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 8397: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 8453: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 8453: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 8487: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 8487: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 8547: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 8547: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 9106: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 9106: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 9152: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 9152: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 9297: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 9297: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 9360: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 9360: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 9511: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 9511: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 9563: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 9563: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 9768: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 9768: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 9872: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 9872: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 9877: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 9877: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 10427: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 10427: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 10449: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 10449: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 10702: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 10702: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 10743: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 10743: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 10760: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 10760: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 10776: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 10776: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 10778: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 10778: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 10942: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 10942: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 10971: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 10971: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 11007: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 11007: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 11094: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 11094: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 11137: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 11137: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 11187: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 11187: Ambiguous Chromosome with no HGNC ID found.
# ❌ Row 11241: Neither x_hgnc_id nor y_hgnc_id has a value.
# ❌ Index 11241: Ambiguous Chromosome with no HGNC ID found.
# Total genes in list: 53
# Sample of gene_list: ['ACRC', 'APOOL', 'ARHGAP4', 'ARHGAP4', 'ARHGEF6']
# ▶️ Checking gene: ACRC
# ✅ Extracted HGNC ID for ACRC: 15805
# ▶️ Checking gene: APOOL
# ✅ Extracted HGNC ID for APOOL: 24009
# ▶️ Checking gene: ARHGAP4
# ✅ Extracted HGNC ID for ARHGAP4: 674
# ▶️ Checking gene: ARHGAP4
# ✅ Extracted HGNC ID for ARHGAP4: 674
# ▶️ Checking gene: ARHGEF6
# ✅ Extracted HGNC ID for ARHGEF6: 685
# ▶️ Checking gene: ARHGEF6
# ✅ Extracted HGNC ID for ARHGEF6: 685
# ▶️ Checking gene: BEND2
# ✅ Extracted HGNC ID for BEND2: 28509
# ▶️ Checking gene: BMX
# ✅ Extracted HGNC ID for BMX: 1079
# ▶️ Checking gene: CSF2RA
# ✅ Extracted HGNC ID for CSF2RA: 2435
# ▶️ Checking gene: DMD
# ✅ Extracted HGNC ID for DMD: 2928
# ▶️ Checking gene: ERCC6L
# ✅ Extracted HGNC ID for ERCC6L: 20794
# ▶️ Checking gene: GJB1
# ✅ Extracted HGNC ID for GJB1: 4283
# ▶️ Checking gene: GUCY2F
# ✅ Extracted HGNC ID for GUCY2F: 4691
# ▶️ Checking gene: HAUS7
# ✅ Extracted HGNC ID for HAUS7: 32979
# ▶️ Checking gene: HCFC1
# ✅ Extracted HGNC ID for HCFC1: 4839
# ▶️ Checking gene: HUWE1
# ✅ Extracted HGNC ID for HUWE1: 30892
# ▶️ Checking gene: KDM5C
# ✅ Extracted HGNC ID for KDM5C: 11114
# ▶️ Checking gene: MAGEB1
# ✅ Extracted HGNC ID for MAGEB1: 6808
# ▶️ Checking gene: MAGEB2
# ✅ Extracted HGNC ID for MAGEB2: 6809
# ▶️ Checking gene: MAGEB2
# ✅ Extracted HGNC ID for MAGEB2: 6809
# ▶️ Checking gene: MAP3K15
# ✅ Extracted HGNC ID for MAP3K15: 31689
# ▶️ Checking gene: MED12
# ✅ Extracted HGNC ID for MED12: 11957
# ▶️ Checking gene: MORC4
# ✅ Extracted HGNC ID for MORC4: 23485
# ▶️ Checking gene: NKRF
# ✅ Extracted HGNC ID for NKRF: 19374
# ▶️ Checking gene: PHF16
# ✅ Extracted HGNC ID for PHF16: 22982
# ▶️ Checking gene: PNMA5
# ✅ Extracted HGNC ID for PNMA5: 18743
# ▶️ Checking gene: RBM10
# ✅ Extracted HGNC ID for RBM10: 9896
# ▶️ Checking gene: RENBP
# ✅ Extracted HGNC ID for RENBP: 9959
# ▶️ Checking gene: RGAG1
# ✅ Extracted HGNC ID for RGAG1: 29245
# ▶️ Checking gene: RIPPLY1
# ✅ Extracted HGNC ID for RIPPLY1: 25117
# ▶️ Checking gene: SLC16A2
# ✅ Extracted HGNC ID for SLC16A2: 10923
# ▶️ Checking gene: SLC25A14
# ✅ Extracted HGNC ID for SLC25A14: 10984
# ▶️ Checking gene: SLC9A6
# ✅ Extracted HGNC ID for SLC9A6: 11079
# ▶️ Checking gene: SMS
# ✅ Extracted HGNC ID for SMS: 11123
# ▶️ Checking gene: SPRY3
# ✅ Extracted HGNC ID for SPRY3: 11271
# ▶️ Checking gene: SSX1
# ✅ Extracted HGNC ID for SSX1: 11335
# ▶️ Checking gene: TAB3
# ✅ Extracted HGNC ID for TAB3: 30681
# ▶️ Checking gene: TBX22
# ✅ Extracted HGNC ID for TBX22: 11600
# ▶️ Checking gene: TCEAL6
# ✅ Extracted HGNC ID for TCEAL6: 24553
# ▶️ Checking gene: TSC22D3
# ✅ Extracted HGNC ID for TSC22D3: 3051
# ▶️ Checking gene: TSPYL2
# ✅ Extracted HGNC ID for TSPYL2: 24358
# ▶️ Checking gene: USP11
# ✅ Extracted HGNC ID for USP11: 12609
# ▶️ Checking gene: USP9X
# ✅ Extracted HGNC ID for USP9X: 12632
# ▶️ Checking gene: VAMP7
# ✅ Extracted HGNC ID for VAMP7: 11486
# ▶️ Checking gene: VCX
# ✅ Extracted HGNC ID for VCX: 12667
# ▶️ Checking gene: VCX3B
# ✅ Extracted HGNC ID for VCX3B: 31838
# ▶️ Checking gene: WWC3
# ✅ Extracted HGNC ID for WWC3: 29237
# ▶️ Checking gene: XPNPEP2
# ✅ Extracted HGNC ID for XPNPEP2: 12823
# ▶️ Checking gene: ZBED1
# ✅ Extracted HGNC ID for ZBED1: 447
# ▶️ Checking gene: ZMAT1
# ✅ Extracted HGNC ID for ZMAT1: 29377
# ▶️ Checking gene: ZNF185
# ✅ Extracted HGNC ID for ZNF185: 12976
# ▶️ Checking gene: ZNF280C
# ✅ Extracted HGNC ID for ZNF280C: 25955
# ▶️ Checking gene: ZNF449
# ✅ Extracted HGNC ID for ZNF449: 21039
# gene_hgnc_id
# untested    11561
# 674             2
# 685             2
# 6809            2
# 24358           1
# 10984           1
# 11079           1
# 11123           1
# 11271           1
# 11335           1
# 30681           1
# 11600           1
# 24553           1
# 3051            1
# 12632           1
# 12609           1
# 25117           1
# 11486           1
# 12667           1
# 31838           1
# 29237           1
# 12823           1
# 447             1
# 29377           1
# 12976           1
# 25955           1
# 10923           1
# 9959            1
# 29245           1
# 4839            1
# 24009           1
# 28509           1
# 1079            1
# 2435            1
# 2928            1
# 20794           1
# 4283            1
# 4691            1
# 32979           1
# 30892           1
# 15805           1
# 11114           1
# 6808            1
# 31689           1
# 11957           1
# 23485           1
# 19374           1
# 22982           1
# 18743           1
# 9896            1
# 21039           1
# Name: count, dtype: int64
# Removed 134 rows with duplicated Gnomad_Notation per PATIENT_ID.
# Done!

# %%
df.to_excel('test_file.xlsx')

# %% [markdown]
# ## Assign df to a variable so that you don't need to rerun the previous cells

# %%
df = pd.read_excel('test_file.xlsx',index_col=0)
df.head()
# Out:
#   Hugo_Symbol Chromosome  Start_Position  End_Position         Consequence  \
# 0       ETFDH          4       159603535     159603535    missense_variant
# 1        GJB4          1        35227334      35227334    missense_variant
# 2       MUC5B         11         1272679       1272679    missense_variant
# 3     PCDHAC1          5       140307515     140307515  synonymous_variant
# 4        YAP1         11       102080254     102080254    missense_variant
#
#   Variant_Classification Variant_Type Reference_Allele Tumor_Seq_Allele2  \
# 0      Missense_Mutation          SNP                G                 C
# 1      Missense_Mutation          SNP                G                 A
# 2      Missense_Mutation          SNP                G                 A
# 3                 Silent          SNP                G                 A
# 4      Missense_Mutation          SNP                C                 T
#
#   SAMPLE_ID  ... temp_Gnomad_Notation Chrom_23 Chr23_X Chr23_Y x_hgnc_id  \
# 0  SJDES004  ...      4-159603535-G-C    False   False   False  no_value
# 1  SJDES004  ...       1-35227334-G-A    False   False   False  no_value
# 2  SJDES004  ...       11-1272679-G-A    False   False   False  no_value
# 3  SJDES004  ...      5-140307515-G-A    False   False   False  no_value
# 4  SJDES004  ...     11-102080254-C-T    False   False   False  no_value
#
#   y_hgnc_id    ambig_chrom gene_hgnc_id hgnc_id_match   Gnomad_Notation
# 0  no_value  non-ambiguous     untested      untested   4-159603535-G-C
# 1  no_value  non-ambiguous     untested      untested    1-35227334-G-A
# 2  no_value  non-ambiguous     untested      untested    11-1272679-G-A
# 3  no_value  non-ambiguous     untested      untested   5-140307515-G-A
# 4  no_value  non-ambiguous     untested      untested  11-102080254-C-T
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Variant MappableConcept
# Now with the data from the cBioportal harvester + transformer, we can start writing a loop to get variant data processed

# %%
all_mappings = []

base_url = 'https://normalize.cancervariants.org/variation/to_vrs?q=' #TODO: change to use Python API not REST API
for idx, row in tqdm(df[0:50].iterrows()):
    variant_of_interest = row['Gnomad_Notation']
    var_url = base_url + variant_of_interest
    r = requests.get(var_url)   
    if r.status_code == 200:
        try:
            vrs_id = r.json()['variations'][0]['id'] 
        except:
            vrs_id = f'Error with {variant_of_interest}'
    else:
        vrs_id = 'Not Found'

    mappings = [
                ConceptMapping(
                    coding=Coding(
                        id=vrs_id,
                        code=str(vrs_id),
                        system="https://www.cbioportal.org/",
                    ),
                    relation=Relation.EXACT_MATCH,
                )
            ]
    
    all_mappings.append(mappings)

# Code to convert all mappings to JSON object goes here

print(all_mappings)
# Out:
# 50it [00:13,  3.64it/s]
# [[ConceptMapping(id=None, extensions=None, coding=Coding(id='ga4gh:VA.A_KHwjPFBBTw2J2AwTbiEDYA1AZM0-T0', extensions=None, name=None, system='https://www.cbioportal.org/', systemVersion=None, code=code(root='ga4gh:VA.A_KHwjPFBBTw2J2AwTbiEDYA1AZM0-T0'), iris=None), relation='exactMatch')], [ConceptMapping(id=None, extensions=None, coding=Coding(id='ga4gh:VA.lHm5O2TRaxF1tYvxutOofpC40WTjGHea', extensions=None, name=None, system='https://www.cbioportal.org/', systemVersion=None, code=code(root='ga4gh:VA.lHm5O2TRaxF1tYvxutOofpC40WTjGHea'), iris=None), relation='exactMatch')], [ConceptMapping(id=None, extensions=None, coding=Coding(id='ga4gh:VA.F5cXKsHFc7TKvrcysBAzSUIWzve89eoT', extensions=None, name=None, system='https://www.cbioportal.org/', systemVersion=None, code=code(root='ga4gh:VA.F5cXKsHFc7TKvrcysBAzSUIWzve89eoT'), iris=None), relation='exactMatch')], [ConceptMapping(id=None, extensions=None, coding=Coding(id='ga4gh:VA.8mB3IFMdAVHOn0Pv5sZbijYClEXZhJPi', extensions=None, name=None, system='https://www.cbioportal.org/', systemVersion=None, code=code(root='ga4gh:VA.8mB3IFMdAVHOn0Pv5sZbijYClEXZhJPi'), iris=None), relation='exactMatch')], [ConceptMapping(id=None, extensions=None, coding=Coding(id='ga4gh:VA.xd_6nCuCXrXsaMHFWQQq8ojnZN3uEVGz', extensions=None, name=None, system='https://www.cbioportal.org/', systemVersion=None, code=code(root='ga4gh:VA.xd_6nCuCXrXsaMHFWQQq8ojnZN3uEVGz'), iris=None), relation='exactMatch')], [ConceptMapping(id=None, extensions=None, coding=Coding(id='ga4gh:VA.AwqvUIJJBdNlBmMih3oDoUD8q3HsEvb8', extensions=None, name=None, system='https://www.cbioportal.org/', systemVersion=None, code=code(root='ga4gh:VA.AwqvUIJJBdNlBmMih3oDoUD8q3HsEvb8'), iris=None), relation='exactMatch')], [ConceptMapping(id=None, extensions=None, coding=Coding(id='ga4gh:VA.VF4si6MFFbVmp4cVl9OXv43eneeNa7SQ', extensions=None, name=None, system='https://www.cbioportal.org/', systemVersion=None, code=code(root='ga4gh:VA.VF4si6MFFbVmp4cVl9OXv43eneeNa7SQ'), iris=None), relation='exactMatch')], [ConceptMapping(id=None, extensions=None, coding=Coding(id='ga4gh:VA.3GLUdQnCwbpq08yiTgvgSskgx2RqfYFR', extensions=None, name=None, system='https://www.cbioportal.org/', systemVersion=None, code=code(root='ga4gh:VA.3GLUdQnCwbpq08yiTgvgSskgx2RqfYFR'), iris=None), relation='exactMatch')], [ConceptMapping(id=None, extensions=None, coding=Coding(id='ga4gh:VA.rC-yRKRvR-H0Rqc0moLUOl7mxQXy5FJO', extensions=None, name=None, system='https://www.cbioportal.org/', systemVersion=None, code=code(root='ga4gh:VA.rC-yRKRvR-H0Rqc0moLUOl7mxQXy5FJO'), iris=None), relation='exactMatch')], [ConceptMapping(id=None, extensions=None, coding=Coding(id='ga4gh:VA.zfbzys-v0WB9d5_x02-q2ktrs3ZGUsvR', extensions=None, name=None, system='https://www.cbioportal.org/', systemVersion=None, code=code(root='ga4gh:VA.zfbzys-v0WB9d5_x02-q2ktrs3ZGUsvR'), iris=None), relation='exactMatch')], [ConceptMapping(id=None, extensions=None, coding=Coding(id='ga4gh:VA.DhoikWQkxzQkai9-pJyfBhrxNfzJpnx1', extensions=None, name=None, system='https://www.cbioportal.org/', systemVersion=None, code=code(root='ga4gh:VA.DhoikWQkxzQkai9-pJyfBhrxNfzJpnx1'), iris=None), relation='exactMatch')], [ConceptMapping(id=None, extensions=None, coding=Coding(id='ga4gh:VA.KyOSOeWTcIkYVjNBMxrU4zQYNDXqFhiy', extensions=None, name=None, system='https://www.cbioportal.org/', systemVersion=None, code=code(root='ga4gh:VA.KyOSOeWTcIkYVjNBMxrU4zQYNDXqFhiy'), iris=None), relation='exactMatch')], [ConceptMapping(id=None, extensions=None, coding=Coding(id='ga4gh:VA.Puvuw3qV6BUglnMG24660e8uTscaTh3w', extensions=None, name=None, system='https://www.cbioportal.org/', systemVersion=None, code=code(root='ga4gh:VA.Puvuw3qV6BUglnMG24660e8uTscaTh3w'), iris=None), relation='exactMatch')], [ConceptMapping(id=None, extensions=None, coding=Coding(id='ga4gh:VA.gU9go4j88SXWcc3odrLVdbZ4xFSTiUmu', extensions=None, name=None, system='https://www.cbioportal.org/', systemVersion=None, code=code(root='ga4gh:VA.gU9go4j88SXWcc3odrLVdbZ4xFSTiUmu'), iris ...

# %%
#The mappings should be a ConceptMapping object (ga4gh.core.models.ConceptMapping)
type(mappings[0])
# Out:
# ga4gh.core.models.ConceptMapping

# %%
# inspect full response if code == 200
r.json()
# Out:
# {'search_term': '16-3340401-C-A',
#  'warnings': [],
#  'variations': [{'id': 'ga4gh:VA.ijmmVdDcPm-AvDVr94F9tNJnC61pvkEk',
#    'type': 'Allele',
#    'digest': 'ijmmVdDcPm-AvDVr94F9tNJnC61pvkEk',
#    'location': {'id': 'ga4gh:SL.Wzcz9PAfx1b4LJP_a9B98YB1Wp-K9sxA',
#     'type': 'SequenceLocation',
#     'digest': 'Wzcz9PAfx1b4LJP_a9B98YB1Wp-K9sxA',
#     'sequenceReference': {'type': 'SequenceReference',
#      'refgetAccession': 'SQ.W6wLoIFOn4G7cjopxPxYNk2lcEqhLQFb'},
#     'start': 3340400,
#     'end': 3340401,
#     'sequence': 'C'},
#    'state': {'type': 'LiteralSequenceExpression', 'sequence': 'A'}}],
#  'service_meta_': {'name': 'variation-normalizer',
#   'version': '0.13.0',
#   'response_datetime': '2025-09-30T16:19:30.296216Z',
#   'url': 'https://github.com/cancervariants/variation-normalization'}}

# %% [markdown]
# ## Gene Mappable Concept
# Now with the data from the cBioportal harvester + transformer, we can start writing a loop to get gene data processed

# %%
def _get_exact_gene_mappings(hgnc_id: str, gene_symbol: str) -> list[ConceptMapping]:
        """ Get HGNC gene mapping 

        param hgnc_id: the unique numeric identifier provided by HGNC to each gene (with no "hgnc:" prefix) that is present in the CBP data in the column gene_hgnc_id
        param gene_symbol: the gene symbol provided in the CBP data in the column Hugo_Symbol

        return: Concept Mapping for HGNC Gene
        """

        #if there is a value in the gene_hgnc_id column that is the string "untested"
        if not hgnc_id and hgnc_id == "untested":
            return None
        
        #add the "hgnc:" prefix to the unique numeric identifier
        gene_id = f"hgnc:{hgnc_id}"

        return[
            ConceptMapping(
                coding=Coding(
                    id= gene_id,
                    name=gene_symbol,
                    code=gene_id.upper(),
                    system="https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/",
                ),
                relation=Relation.EXACT_MATCH,
                extensions= [Extension(name="cbioportal_annotation", value=True)],
            )]

# %%
#Check the output behaves as expected
mappings = _get_exact_gene_mappings("13056","ZNF263")
mappings
# Out:
# [ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='cbioportal_annotation', value=True, description=None)], coding=Coding(id='hgnc:13056', extensions=None, name='ZNF263', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:13056'), iris=None), relation='exactMatch')]

# %%
class CBPTransformer(Transformer):
    """A class for transforming CBP to the common data model."""

    def _create_cache(self):
        pass

    def _get_therapeutic_substitute_group(self):
        pass

    def _get_therapy(self):
        pass

    def transform(self):
        pass

    def _add_genes(self, genes:list[dict]) -> list:
        """Create gene objects for all CBP records.

        Mutates instance variables ``_cache.genes`` and ``processed_data.genes``

        :param genes: All genes in CBP
        """
        transform_genes = []

       #for gene in genes: #if want ot remove tqdm for backend
        for gene in tqdm(genes, desc="Processing genes"):

            gene_symbol = gene.get("Hugo_Symbol")
            hgnc_id = gene.get("gene_hgnc_id")


            queries = [hgnc_id, gene_symbol] if hgnc_id and hgnc_id != "untested" else [gene_symbol]
            extensions = []

            normalized_gene_id = None
            gene_norm_resp = None

            for query in queries:
                gene_norm_resp, normalized_gene_id = self.vicc_normalizers.normalize_gene(query)
                if normalized_gene_id:
                    break

            cbp_mappings = _get_exact_gene_mappings(hgnc_id,gene_symbol)

            if not normalized_gene_id:
                _logger.debug(
                    "Gene Normalizer unable to normalize: using queries %s",
                    queries,
                )
                mappings = cbp_mappings
                extensions.append(self._get_vicc_normalizer_failure_ext())
            else:
                mappings = self._get_vicc_normalizer_mappings(normalized_gene_id, gene_norm_resp)
                #self._update_normalizer_mappings(mappings, _get_exact_gene_mappings) 
                #TODO: add this back, figure out how

            cbp_gene = MappableConcept(
                conceptType="Gene",
                name=gene_symbol,
                mappings=mappings,
                extensions=extensions or None,
            )
            transform_genes.append(cbp_gene)

            #self._cache.genes[gene_symbol] = cbp_gene
        return transform_genes

# %%
#Convert CBP data df to a list of dictionaries (each row its own dictionary)
genes = df.to_dict(orient='records')
#Take just a subset to test
sub_genes = genes[0:5]

# %%
transformer = CBPTransformer()
# Out:
# ***Using Gene Database Endpoint: http://localhost:8000***
# Downloading hg19ToHg38.over.chain.gz...
# 100%|██████████| 227698/227698 [00:00<00:00, 763015.03it/s]
# Downloading hg38ToHg19.over.chain.gz...
# 100%|██████████| 1246411/1246411 [00:00<00:00, 2041091.26it/s]

# %%
#Run fxn on subset
transformer._add_genes(sub_genes)
# Out:
# Processing genes: 100%|██████████| 5/5 [00:00<00:00, 21.65it/s]
# [MappableConcept(id=None, extensions=None, conceptType='Gene', name='ETFDH', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:3483', extensions=None, name='ETFDH', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:3483'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:2110', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='2110'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='GJB4', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:4286', extensions=None, name='GJB4', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:4286'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:127534', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='127534'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='MUC5B', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:7516', extensions=None, name='MUC5B', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:7516'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:727897', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='727897'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='PCDHAC1', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:8676', extensions=None, name='PCDHAC1', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:8676'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:56135', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='56135'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='YAP1', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:16262', extensions=None, name='YAP1', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:16262'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:10413', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='10413'), iris=None), relation='exactMatch')])]

# %%
#Run fxn on whole dataset(~6 min)
transformer._add_genes(genes)
# Out:
# Processing genes: 100%|██████████| 11480/11480 [04:47<00:00, 39.96it/s]
# [MappableConcept(id=None, extensions=None, conceptType='Gene', name='ETFDH', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:3483', extensions=None, name='ETFDH', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:3483'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:2110', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='2110'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='GJB4', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:4286', extensions=None, name='GJB4', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:4286'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:127534', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='127534'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='MUC5B', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:7516', extensions=None, name='MUC5B', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:7516'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:727897', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='727897'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='PCDHAC1', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:8676', extensions=None, name='PCDHAC1', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:8676'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:56135', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='56135'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='YAP1', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:16262', extensions=None, name='YAP1', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:16262'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:10413', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='10413'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ZNF10', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:12879', extensions=None, name='ZNF10', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:12879'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:7556', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='7556'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ACACA', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:84', extensions=None, name='ACACA', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:84'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:31', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='31'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='CAMKK2', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:1470', extensions=None, name='CAMKK2', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:1470'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:10645', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='10645'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='CTNNA3', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:2511', extensions=None, name='CTNNA3', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:2511'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:29119', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='29119'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='FAT3', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:23112', extensions=None, name='FAT3', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:23112'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:120114', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='120114'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='OR2M2', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:8268', extensions=None, name='OR2M2', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:8268'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:391194', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='391194'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='PAX4', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:8618', extensions=None, name='PAX4', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:8618'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:5078', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='5078'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='PNPLA7', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:24768', extensions=None, name='PNPLA7', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:24768'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:375775', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='375775'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='PSD4', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:19096', extensions=None, name='PSD4', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:19096'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:23550', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='23550'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ZC3H15', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:29528', extensions=None, name='ZC3H15', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:29528'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:55854', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='55854'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ACP2', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:123', extensions=None, name='ACP2', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:123'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:53', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='53'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='AHI1', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:21575', extensions=None, name='AHI1', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:21575'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:54806', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='54806'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='AVP', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:894', extensions=None, name='AVP', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:894'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:551', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='551'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='BEND7', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:23514', extensions=None, name='BEND7', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:23514'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:222389', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='222389'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='CACNG3', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:1407', extensions=None, name='CACNG3', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:1407'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:10368', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='10368'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='CALCOCO2', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:29912', extensions=None, name='CALCOCO2', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:29912'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:10241', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='10241'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='CPEB1', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:21744', extensions=None, name='CPEB1', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:21744'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:64506', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='64506'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='CYP26A1', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:2603', extensions=None, name='CYP26A1', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:2603'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:1592', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='1592'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='DBF4', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:17364', extensions=None, name='DBF4', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:17364'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:10926', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='10926'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='DVL3', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:3087', extensions=None, name='DVL3', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:3087'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:1857', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='1857'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ENAM', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:3344', extensions=None, name='ENAM', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:3344'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:10117', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='10117'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='FHL1', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:3702', extensions=None, name='FHL1', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:3702'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:2273', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='2273'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='FOXR2', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:30469', extensions=None, name='FOXR2', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:30469'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:139628', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='139628'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='GBP7', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:29606', extensions=None, name='GBP7', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:29606'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:388646', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='388646'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ITGA2', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:6137', extensions=None, name='ITGA2', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:6137'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:3673', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='3673'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='KDM2A', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:13606', extensions=None, name='KDM2A', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:13606'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:22992', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='22992'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='KIAA1704', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:20298', extensions=None, name='GPALPP1', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:20298'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:55425', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='55425'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='KRI1', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:25769', extensions=None, name='KRI1', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:25769'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:65095', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='65095'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='KRTAP10-3', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:22968', extensions=None, name='KRTAP10-3', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:22968'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:386682', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='386682'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='LIMK2', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:6614', extensions=None, name='LIMK2', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:6614'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:3985', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='3985'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='MAML3', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:16272', extensions=None, name='MAML3', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:16272'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:55534', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='55534'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='MBD6', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:20445', extensions=None, name='MBD6', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:20445'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:114785', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='114785'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='MTR', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:7468', extensions=None, name='MTR', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:7468'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:4548', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='4548'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='OCM', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:8105', extensions=None, name='OCM', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:8105'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:654231', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='654231'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='OTOP2', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:19657', extensions=None, name='OTOP2', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:19657'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:92736', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='92736'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='PDE4A', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:8780', extensions=None, name='PDE4A', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:8780'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:5141', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='5141'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='STAG2', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:11355', extensions=None, name='STAG2', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:11355'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:10735', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='10735'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='SYT15', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:17167', extensions=None, name='SYT15', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:17167'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:83849', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='83849'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='TCOF1', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:11654', extensions=None, name='TCOF1', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:11654'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:6949', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='6949'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='VEZF1', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:12949', extensions=None, name='VEZF1', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:12949'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:7716', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='7716'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='XAB2', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:14089', extensions=None, name='XAB2', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:14089'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:56949', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='56949'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ZFC3H1', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:28328', extensions=None, name='ZFC3H1', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:28328'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:196441', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='196441'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ZFYVE26', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:20761', extensions=None, name='ZFYVE26', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:20761'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:23503', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='23503'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ZMYM4', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:13055', extensions=None, name='ZMYM4', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:13055'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:9202', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='9202'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ZNF263', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:13056', extensions=None, name='ZNF263', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:13056'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:10127', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='10127'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ZNF443', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:20878', extensions=None, name='ZNF443', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:20878'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:10224', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='10224'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ZNF563', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:30498', extensions=None, name='ZNF563', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:30498'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:147837', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='147837'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ZNF878', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:37246', extensions=None, name='ZNF878', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:37246'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:729747', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='729747'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ERCC3', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:3435', extensions=None, name='ERCC3', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:3435'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:2071', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='2071'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ZNF335', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:15807', extensions=None, name='ZNF335', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:15807'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:63925', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='63925'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='CD22', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:1643', extensions=None, name='CD22', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:1643'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:933', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='933'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='GPM6B', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:4461', extensions=None, name='GPM6B', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:4461'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:2824', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='2824'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='HPS3', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:15597', extensions=None, name='HPS3', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:15597'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:84343', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='84343'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='SLC5A11', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:23091', extensions=None, name='SLC5A11', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:23091'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:115584', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='115584'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='BSDC1', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:25501', extensions=None, name='BSDC1', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:25501'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:55108', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='55108'), iris=None), relation='exactMatch')]),
# ...
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALG5', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:20266', extensions=None, name='ALG5', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:20266'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:29880', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='29880'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALK', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:427', extensions=None, name='ALK', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:427'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:238', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='238'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALK', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:427', extensions=None, name='ALK', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:427'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:238', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='238'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALKBH5', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:25996', extensions=None, name='ALKBH5', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:25996'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:54890', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='54890'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALKBH7', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:21306', extensions=None, name='ALKBH7', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:21306'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:84266', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='84266'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALMS1', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:428', extensions=None, name='ALMS1', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:428'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:7840', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='7840'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALMS1', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:428', extensions=None, name='ALMS1', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:428'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:7840', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='7840'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALOX12', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:429', extensions=None, name='ALOX12', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:429'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:239', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='239'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALOX12', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:429', extensions=None, name='ALOX12', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:429'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:239', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='239'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALOX15', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:433', extensions=None, name='ALOX15', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:433'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:246', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='246'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALOX15B', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:434', extensions=None, name='ALOX15B', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:434'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:247', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='247'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALOXE3', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:13743', extensions=None, name='ALOXE3', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:13743'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:59344', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='59344'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALPI', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:437', extensions=None, name='ALPI', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:437'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:248', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='248'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALPK2', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:20565', extensions=None, name='ALPK2', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:20565'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:115701', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='115701'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALPK2', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:20565', extensions=None, name='ALPK2', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:20565'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:115701', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='115701'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALPK2', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:20565', extensions=None, name='ALPK2', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:20565'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:115701', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='115701'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALPK3', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:17574', extensions=None, name='ALPK3', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:17574'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:57538', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='57538'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALPK3', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:17574', extensions=None, name='ALPK3', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:17574'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:57538', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='57538'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALPK3', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:17574', extensions=None, name='ALPK3', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:17574'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:57538', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='57538'), iris=None), relation='exactMatch')]),
#  MappableConcept(id=None, extensions=None, conceptType='Gene', name='ALPL', primaryCoding=None, mappings=[ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=True, description=None)], coding=Coding(id='hgnc:438', extensions=None, name='ALPL', system='https://www.genenames.org/data/gene-symbol-report/#!/hgnc_id/', systemVersion=None, code=code(root='HGNC:438'), iris=None), relation='exactMatch'), ConceptMapping(id=None, extensions=[Extension(id=None, extensions=None, name='vicc_normalizer_priority', value=False, description=None)], coding=Coding(id='ncbigene:249', extensions=None, name=None, system='https://www.ncbi.nlm.nih.gov/gene/', systemVersion=None, code=code(root='249'), iris=None), relation='exactMatch')]),
#  ...]
