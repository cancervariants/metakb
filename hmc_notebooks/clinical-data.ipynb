# %%
import json
import requests

# %%
# Grab the list of Sample IDs from study
study_name = 'pptc_2019'

url = f'https://www.cbioportal.org/api/sample-lists/{study_name}_all'

response = requests.get(url)
sampleIds = response.json()['sampleIds']

sampleIds[0:5]
# Out:
# ['ALL-03', 'MLL-1', 'MLL-14', 'MLL-2', 'MLL-3']

# %% [markdown]
# ## Grabbing Clinical Data
# With a study name and a list of sampleIDs we can pull attributes directly from cBioPortal in a study specific manner. We can use the swaggerUI write-up to help us determine how to format our POST request.
#
# Our expected request body is given to us from a combination of the description and the required Request Body section. The description tells us that it is expecting patientIDs or sampleIDs while the request body says it is expecting the format:
#
# ```
# {
#   "ids": [
#     "string"
#   ],
#   "attributeIds": [
#     "string"
#   ]
# }
# ```
#
# We will use the IDs field to submit our sampleIDs. It is expecting a list of strings so we are good on that end.
#
# Next we need to select the correct parameters for our request. It seems like cBioPortal allows the selection of the level of detail of the response as a specific parameter called "projection". This value can be SUMMARY, DETAILED, or META. For our calculation purposes I think we'll need either DETAILED or SUMMARY, as I'm not quite sure what META is supposed to give and I can't get it to give anything other than a blank response (as indicated by the DECODE error). These different parameter URLs are reflected in the options 1 through 3 below.

# %%
# Grab clinical data using a list of sampleIDs
option_1 = f'https://www.cbioportal.org/api/studies/{study_name}/clinical-data/fetch?clinicalDataType=SAMPLE&projection=DETAILED'
option_2 = f'https://www.cbioportal.org/api/studies/{study_name}/clinical-data/fetch?clinicalDataType=SAMPLE&projection=SUMMARY'
option_3 = f'https://www.cbioportal.org/api/studies/{study_name}/clinical-data/fetch?clinicalDataType=SAMPLE&projection=META'

# Format our sample IDs as a json type object
data = {
    "ids": sampleIds
}

# Tell the cBioPortal resource to expect JSON
headers = {
    "Content-Type": "application/json",
    "Accept": "application/json"
}

response = requests.post(option_1,data=json.dumps(data), headers=headers)

if response.status_code == 200:
    clinical_data = response.json()  # Convert response to a Python dictionary
    print("Success", response.status_code)
else:
    print("Error fetching clinical data:", response.status_code)
    print("Response text:", response.text)
# Out:
# Success 200

# %%
clinical_data
# Out:
# [{'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Cancer Subtype Curated',
#    'description': 'Cancer Subtype Curated',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '5',
#    'clinicalAttributeId': 'CANCER_SUBTYPE_CURATED',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'CANCER_SUBTYPE_CURATED',
#   'value': 'MLL-ALL'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Cancer Type',
#    'description': 'Cancer Type',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '1',
#    'clinicalAttributeId': 'CANCER_TYPE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'CANCER_TYPE',
#   'value': 'Leukemia'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Cancer Type Detailed',
#    'description': 'Cancer Type Detailed',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '1',
#    'clinicalAttributeId': 'CANCER_TYPE_DETAILED',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'CANCER_TYPE_DETAILED',
#   'value': 'Acute Leukemias of Ambiguous Lineage'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'EXPRESSION',
#    'description': 'EXPRESSION',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '2',
#    'clinicalAttributeId': 'EXPRESSION',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'EXPRESSION',
#   'value': 'NO'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Fraction Genome Altered',
#    'description': 'Fraction Genome Altered',
#    'datatype': 'NUMBER',
#    'patientAttribute': False,
#    'priority': '20',
#    'clinicalAttributeId': 'FRACTION_GENOME_ALTERED',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'FRACTION_GENOME_ALTERED',
#   'value': '0.0004'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'HISTOPATHOLOGY',
#    'description': 'HISTOPATHOLOGY',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '3',
#    'clinicalAttributeId': 'HISTOPATHOLOGY',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'HISTOPATHOLOGY',
#   'value': 't(11;19), MLL-MLLT1'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Mutation Count',
#    'description': 'Mutation Count',
#    'datatype': 'NUMBER',
#    'patientAttribute': False,
#    'priority': '30',
#    'clinicalAttributeId': 'MUTATION_COUNT',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'MUTATION_COUNT',
#   'value': '132'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Note',
#    'description': 'Note.',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '2',
#    'clinicalAttributeId': 'NOTE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'NOTE',
#   'value': 'Lock'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Oncotree Code',
#    'description': 'Oncotree Code',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '1',
#    'clinicalAttributeId': 'ONCOTREE_CODE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'ONCOTREE_CODE',
#   'value': 'ALAL'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'PHASE',
#    'description': 'PHASE',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '4',
#    'clinicalAttributeId': 'PHASE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'PHASE',
#   'value': 'Diagnosis'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Site of Sample',
#    'description': 'Sample Site',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '4',
#    'clinicalAttributeId': 'SAMPLE_SITE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'SAMPLE_SITE',
#   'value': 'Unknown'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'SPECIMEN_SITE',
#    'description': 'SPECIMEN_SITE',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '4',
#    'clinicalAttributeId': 'SITE_OF_SPECIMEN',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'SITE_OF_SPECIMEN',
#   'value': 'Bone marrow'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'TMB (nonsynonymous)',
#    'description': 'TMB (nonsynonymous)',
#    'datatype': 'NUMBER',
#    'patientAttribute': False,
#    'priority': '1',
#    'clinicalAttributeId': 'TMB_NONSYNONYMOUS',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TMB_NONSYNONYMOUS',
#   'value': '4.4'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment 17-DMAG',
#    'description': 'Treatment 17-DMAG',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_17-DMAG',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_17-DMAG',
#   'value': '2'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment 19D12',
#    'description': 'Treatment 19D12',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_19D12',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_19D12',
#   'value': '1'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment ABRAXANE',
#    'description': 'Treatment ABRAXANE',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_ABRAXANE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_ABRAXANE',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment ABT-199',
#    'description': 'Treatment ABT-199',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_ABT-199',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_ABT-199',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment ABT-263',
#    'description': 'Treatment ABT-263',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_ABT-263',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_ABT-263',
#   'value': '5'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment ACTINOMYCIN D',
#    'description': 'Treatment ACTINOMYCIN D',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_ACTINOMYCIN D',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_ACTINOMYCIN D',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment APLIDIN',
#    'description': 'Treatment APLIDIN',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_APLIDIN',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_APLIDIN',
#   'value': '3'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment AZD-2171',
#    'description': 'Treatment AZD-2171',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_AZD-2171',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_AZD-2171',
#   'value': '1'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment AZD-6244',
#    'description': 'Treatment AZD-6244',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_AZD-6244',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_AZD-6244',
#   'value': '2'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment AZD1480',
#    'description': 'Treatment AZD1480',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_AZD1480',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_AZD1480',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment AZD8055',
#    'description': 'Treatment AZD8055',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_AZD8055',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_AZD8055',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment BAL101553',
#    'description': 'Treatment BAL101553',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_BAL101553',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_BAL101553',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment BI6727 (VOLASERTIB)',
#    'description': 'Treatment BI6727 (VOLASERTIB)',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_BI6727 (VOLASERTIB)',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_BI6727 (VOLASERTIB)',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment BMN-673',
#    'description': 'Treatment BMN-673',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_BMN-673',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_BMN-673',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment BMS-354825',
#    'description': 'Treatment BMS-354825',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_BMS-354825',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_BMS-354825',
#   'value': '3'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment BMS-754807',
#    'description': 'Treatment BMS-754807',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_BMS-754807',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_BMS-754807',
#   'value': '1'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment BORTEZOMIB',
#    'description': 'Treatment BORTEZOMIB',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_BORTEZOMIB',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_BORTEZOMIB',
#   'value': '2'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment CABOZANTINIB (XL-148)',
#    'description': 'Treatment CABOZANTINIB (XL-148)',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_CABOZANTINIB (XL-148)',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_CABOZANTINIB (XL-148)',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment CBL0137',
#    'description': 'Treatment CBL0137',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_CBL0137',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_CBL0137',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment CDX-011 (GLEMBATUMUMAB)',
#    'description': 'Treatment CDX-011 (GLEMBATUMUMAB)',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_CDX-011 (GLEMBATUMUMAB)',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_CDX-011 (GLEMBATUMUMAB)',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment CGC(PG)-11047',
#    'description': 'Treatment CGC(PG)-11047',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_CGC(PG)-11047',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_CGC(PG)-11047',
#   'value': '2'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment CISPLATIN',
#    'description': 'Treatment CISPLATIN',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_CISPLATIN',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_CISPLATIN',
#   'value': '2'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment CLORETAZINE',
#    'description': 'Treatment CLORETAZINE',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_CLORETAZINE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_CLORETAZINE',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment CPX351',
#    'description': 'Treatment CPX351',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_CPX351',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_CPX351',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment CX-5461 (POL1)',
#    'description': 'Treatment CX-5461 (POL1)',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_CX-5461 (POL1)',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_CX-5461 (POL1)',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment CYCLOPHOSPHAMIDE',
#    'description': 'Treatment CYCLOPHOSPHAMIDE',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_CYCLOPHOSPHAMIDE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_CYCLOPHOSPHAMIDE',
#   'value': '6'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment CYTARABINE',
#    'description': 'Treatment CYTARABINE',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_CYTARABINE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_CYTARABINE',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment E7438/EPZ6438',
#    'description': 'Treatment E7438/EPZ6438',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_E7438/EPZ6438',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_E7438/EPZ6438',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment EC1456',
#    'description': 'Treatment EC1456',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_EC1456',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_EC1456',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment ERIBULIN',
#    'description': 'Treatment ERIBULIN',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_ERIBULIN',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_ERIBULIN',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment FENRETINIDE',
#    'description': 'Treatment FENRETINIDE',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_FENRETINIDE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_FENRETINIDE',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment GENZ-644282',
#    'description': 'Treatment GENZ-644282',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_GENZ-644282',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_GENZ-644282',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment GS-9820',
#    'description': 'Treatment GS-9820',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_GS-9820',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_GS-9820',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment GSK690693',
#    'description': 'Treatment GSK690693',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_GSK690693',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_GSK690693',
#   'value': '1'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment GSK923295A',
#    'description': 'Treatment GSK923295A',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_GSK923295A',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_GSK923295A',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment HGS-ETR1',
#    'description': 'Treatment HGS-ETR1',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_HGS-ETR1',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_HGS-ETR1',
#   'value': '1'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment IMC-A12',
#    'description': 'Treatment IMC-A12',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_IMC-A12',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_IMC-A12',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment INK128-1110-028',
#    'description': 'Treatment INK128-1110-028',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_INK128-1110-028',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_INK128-1110-028',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment JNJ26481585',
#    'description': 'Treatment JNJ26481585',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_JNJ26481585',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_JNJ26481585',
#   'value': '3'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment JNJ26854165',
#    'description': 'Treatment JNJ26854165',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_JNJ26854165',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_JNJ26854165',
#   'value': '4'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment KPT-330',
#    'description': 'Treatment KPT-330',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_KPT-330',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_KPT-330',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment LAPATINIB',
#    'description': 'Treatment LAPATINIB',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_LAPATINIB',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_LAPATINIB',
#   'value': '1'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment LENOLIDAMIDE',
#    'description': 'Treatment LENOLIDAMIDE',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_LENOLIDAMIDE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_LENOLIDAMIDE',
#   'value': '1'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment LY 2606368',
#    'description': 'Treatment LY 2606368',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_LY 2606368',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_LY 2606368',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment MK-2206',
#    'description': 'Treatment MK-2206',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_MK-2206',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_MK-2206',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment MK-8242',
#    'description': 'Treatment MK-8242',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_MK-8242',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_MK-8242',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment MLN4924',
#    'description': 'Treatment MLN4924',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_MLN4924',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_MLN4924',
#   'value': '3'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment MLN8237',
#    'description': 'Treatment MLN8237',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_MLN8237',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_MLN8237',
#   'value': '5'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment MM-141',
#    'description': 'Treatment MM-141',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_MM-141',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_MM-141',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment NSC060043',
#    'description': 'Treatment NSC060043',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_NSC060043',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_NSC060043',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment NSC750854',
#    'description': 'Treatment NSC750854',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_NSC750854',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_NSC750854',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment PCI-32765',
#    'description': 'Treatment PCI-32765',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_PCI-32765',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_PCI-32765',
#   'value': '1'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment PF-03084014',
#    'description': 'Treatment PF-03084014',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_PF-03084014',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_PF-03084014',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment PIXANTRONE',
#    'description': 'Treatment PIXANTRONE',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_PIXANTRONE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_PIXANTRONE',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment PR-104',
#    'description': 'Treatment PR-104',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_PR-104',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_PR-104',
#   'value': '6'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment RAPAMYCIN',
#    'description': 'Treatment RAPAMYCIN',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_RAPAMYCIN',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_RAPAMYCIN',
#   'value': '2'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment RG7112',
#    'description': 'Treatment RG7112',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_RG7112',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_RG7112',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment RO4929097',
#    'description': 'Treatment RO4929097',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_RO4929097',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_RO4929097',
#   'value': '1'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment RUXOLITINIB',
#    'description': 'Treatment RUXOLITINIB',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_RUXOLITINIB',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_RUXOLITINIB',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment SAHA',
#    'description': 'Treatment SAHA',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_SAHA',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_SAHA',
#   'value': '1'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment SAR3419',
#    'description': 'Treatment SAR3419',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_SAR3419',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_SAR3419',
#   'value': '2'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment SB-715992',
#    'description': 'Treatment SB-715992',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_SB-715992',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_SB-715992',
#   'value': '4'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment SCH 727965',
#    'description': 'Treatment SCH 727965',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_SCH 727965',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_SCH 727965',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment SGI-1776',
#    'description': 'Treatment SGI-1776',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_SGI-1776',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_SGI-1776',
#   'value': '1'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment SGN-CD19A',
#    'description': 'Treatment SGN-CD19A',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_SGN-CD19A',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_SGN-CD19A',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment SORAFENIB',
#    'description': 'Treatment SORAFENIB',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_SORAFENIB',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_SORAFENIB',
#   'value': '1'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment STA9090 (GANETESPIB)',
#    'description': 'Treatment STA9090 (GANETESPIB)',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_STA9090 (GANETESPIB)',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_STA9090 (GANETESPIB)',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment STF-118804',
#    'description': 'Treatment STF-118804',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_STF-118804',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_STF-118804',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment SU11248',
#    'description': 'Treatment SU11248',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_SU11248',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_SU11248',
#   'value': '2'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment SVV-001',
#    'description': 'Treatment SVV-001',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_SVV-001',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_SVV-001',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment TAK-701',
#    'description': 'Treatment TAK-701',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_TAK-701',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_TAK-701',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment TB-403',
#    'description': 'Treatment TB-403',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_TB-403',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_TB-403',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment TL32711',
#    'description': 'Treatment TL32711',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_TL32711',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_TL32711',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment TOPOTECAN',
#    'description': 'Treatment TOPOTECAN',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_TOPOTECAN',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_TOPOTECAN',
#   'value': '5'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment TRISENOX(ATO)',
#    'description': 'Treatment TRISENOX(ATO)',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_TRISENOX(ATO)',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_TRISENOX(ATO)',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment VINCRISTINE',
#    'description': 'Treatment VINCRISTINE',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_VINCRISTINE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_VINCRISTINE',
#   'value': '6'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment VS-4718',
#    'description': 'Treatment VS-4718',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_VS-4718',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_VS-4718',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment XL147',
#    'description': 'Treatment XL147',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_XL147',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_XL147',
#   'value': '0'},
#  {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5',
#   'sampleId': 'ALL-03',
#   'patientId': 'P0002',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Treatment XL765',
#    'description': 'Treatment XL765',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '0',
#    'clinicalAttributeId': 'TX_XL765',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TX_XL765',
#   'value': '0'},
#  {'uniqueSampleKey': 'TUxMLTE6cHB0Y18yMDE5',
#   'uniquePatientKey': 'UDAxNTY6cHB0Y18yMDE5',
#   'sampleId': 'MLL-1',
#   'patientId': 'P0156',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Cancer Subtype Curated',
#    'description': 'Cancer Subtype Curated',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '5',
#    'clinicalAttributeId': 'CANCER_SUBTYPE_CURATED',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'CANCER_SUBTYPE_CURATED',
#   'value': 'MLL-ALL'},
#  {'uniqueSampleKey': 'TUxMLTE6cHB0Y18yMDE5',
#   'uniquePatientKey': 'UDAxNTY6cHB0Y18yMDE5',
#   'sampleId': 'MLL-1',
#   'patientId': 'P0156',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Cancer Type',
#    'description': 'Cancer Type',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '1',
#    'clinicalAttributeId': 'CANCER_TYPE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'CANCER_TYPE',
#   'value': 'Leukemia'},
#  {'uniqueSampleKey': 'TUxMLTE6cHB0Y18yMDE5',
#   'uniquePatientKey': 'UDAxNTY6cHB0Y18yMDE5',
#   'sampleId': 'MLL-1',
#   'patientId': 'P0156',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Cancer Type Detailed',
#    'description': 'Cancer Type Detailed',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '1',
#    'clinicalAttributeId': 'CANCER_TYPE_DETAILED',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'CANCER_TYPE_DETAILED',
#   'value': 'Acute Leukemias of Ambiguous Lineage'},
#  {'uniqueSampleKey': 'TUxMLTE6cHB0Y18yMDE5',
#   'uniquePatientKey': 'UDAxNTY6cHB0Y18yMDE5',
#   'sampleId': 'MLL-1',
# ...
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'TMB (nonsynonymous)',
#    'description': 'TMB (nonsynonymous)',
#    'datatype': 'NUMBER',
#    'patientAttribute': False,
#    'priority': '1',
#    'clinicalAttributeId': 'TMB_NONSYNONYMOUS',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TMB_NONSYNONYMOUS',
#   'value': '3.7'},
#  {'uniqueSampleKey': 'SUNiLTUxMDhBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzQ6cHB0Y18yMDE5',
#   'sampleId': 'ICb-5108ATRT',
#   'patientId': 'P0134',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Cancer Subtype Curated',
#    'description': 'Cancer Subtype Curated',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '5',
#    'clinicalAttributeId': 'CANCER_SUBTYPE_CURATED',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'CANCER_SUBTYPE_CURATED',
#   'value': 'ATRT'},
#  {'uniqueSampleKey': 'SUNiLTUxMDhBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzQ6cHB0Y18yMDE5',
#   'sampleId': 'ICb-5108ATRT',
#   'patientId': 'P0134',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Cancer Type',
#    'description': 'Cancer Type',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '1',
#    'clinicalAttributeId': 'CANCER_TYPE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'CANCER_TYPE',
#   'value': 'Embryonal Tumor'},
#  {'uniqueSampleKey': 'SUNiLTUxMDhBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzQ6cHB0Y18yMDE5',
#   'sampleId': 'ICb-5108ATRT',
#   'patientId': 'P0134',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Cancer Type Detailed',
#    'description': 'Cancer Type Detailed',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '1',
#    'clinicalAttributeId': 'CANCER_TYPE_DETAILED',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'CANCER_TYPE_DETAILED',
#   'value': 'Atypical Teratoid/Rhabdoid Tumor'},
#  {'uniqueSampleKey': 'SUNiLTUxMDhBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzQ6cHB0Y18yMDE5',
#   'sampleId': 'ICb-5108ATRT',
#   'patientId': 'P0134',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'EXPRESSION',
#    'description': 'EXPRESSION',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '2',
#    'clinicalAttributeId': 'EXPRESSION',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'EXPRESSION',
#   'value': 'NO'},
#  {'uniqueSampleKey': 'SUNiLTUxMDhBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzQ6cHB0Y18yMDE5',
#   'sampleId': 'ICb-5108ATRT',
#   'patientId': 'P0134',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Fraction Genome Altered',
#    'description': 'Fraction Genome Altered',
#    'datatype': 'NUMBER',
#    'patientAttribute': False,
#    'priority': '20',
#    'clinicalAttributeId': 'FRACTION_GENOME_ALTERED',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'FRACTION_GENOME_ALTERED',
#   'value': '0.0047'},
#  {'uniqueSampleKey': 'SUNiLTUxMDhBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzQ6cHB0Y18yMDE5',
#   'sampleId': 'ICb-5108ATRT',
#   'patientId': 'P0134',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'HISTOPATHOLOGY',
#    'description': 'HISTOPATHOLOGY',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '3',
#    'clinicalAttributeId': 'HISTOPATHOLOGY',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'HISTOPATHOLOGY',
#   'value': 'MYC by pathology and RNA'},
#  {'uniqueSampleKey': 'SUNiLTUxMDhBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzQ6cHB0Y18yMDE5',
#   'sampleId': 'ICb-5108ATRT',
#   'patientId': 'P0134',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Mutation Count',
#    'description': 'Mutation Count',
#    'datatype': 'NUMBER',
#    'patientAttribute': False,
#    'priority': '30',
#    'clinicalAttributeId': 'MUTATION_COUNT',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'MUTATION_COUNT',
#   'value': '126'},
#  {'uniqueSampleKey': 'SUNiLTUxMDhBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzQ6cHB0Y18yMDE5',
#   'sampleId': 'ICb-5108ATRT',
#   'patientId': 'P0134',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Note',
#    'description': 'Note.',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '2',
#    'clinicalAttributeId': 'NOTE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'NOTE',
#   'value': 'Li, XN'},
#  {'uniqueSampleKey': 'SUNiLTUxMDhBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzQ6cHB0Y18yMDE5',
#   'sampleId': 'ICb-5108ATRT',
#   'patientId': 'P0134',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Oncotree Code',
#    'description': 'Oncotree Code',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '1',
#    'clinicalAttributeId': 'ONCOTREE_CODE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'ONCOTREE_CODE',
#   'value': 'ATRT'},
#  {'uniqueSampleKey': 'SUNiLTUxMDhBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzQ6cHB0Y18yMDE5',
#   'sampleId': 'ICb-5108ATRT',
#   'patientId': 'P0134',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'PHASE',
#    'description': 'PHASE',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '4',
#    'clinicalAttributeId': 'PHASE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'PHASE',
#   'value': 'Diagnosis'},
#  {'uniqueSampleKey': 'SUNiLTUxMDhBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzQ6cHB0Y18yMDE5',
#   'sampleId': 'ICb-5108ATRT',
#   'patientId': 'P0134',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Site of Sample',
#    'description': 'Sample Site',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '4',
#    'clinicalAttributeId': 'SAMPLE_SITE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'SAMPLE_SITE',
#   'value': 'Cerebellum'},
#  {'uniqueSampleKey': 'SUNiLTUxMDhBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzQ6cHB0Y18yMDE5',
#   'sampleId': 'ICb-5108ATRT',
#   'patientId': 'P0134',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'SPECIMEN_SITE',
#    'description': 'SPECIMEN_SITE',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '4',
#    'clinicalAttributeId': 'SITE_OF_SPECIMEN',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'SITE_OF_SPECIMEN',
#   'value': 'Cerebellum'},
#  {'uniqueSampleKey': 'SUNiLTUxMDhBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzQ6cHB0Y18yMDE5',
#   'sampleId': 'ICb-5108ATRT',
#   'patientId': 'P0134',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'TMB (nonsynonymous)',
#    'description': 'TMB (nonsynonymous)',
#    'datatype': 'NUMBER',
#    'patientAttribute': False,
#    'priority': '1',
#    'clinicalAttributeId': 'TMB_NONSYNONYMOUS',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TMB_NONSYNONYMOUS',
#   'value': '4.133333333'},
#  {'uniqueSampleKey': 'SUNiLTY3NTNBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzc6cHB0Y18yMDE5',
#   'sampleId': 'ICb-6753ATRT',
#   'patientId': 'P0137',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Cancer Subtype Curated',
#    'description': 'Cancer Subtype Curated',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '5',
#    'clinicalAttributeId': 'CANCER_SUBTYPE_CURATED',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'CANCER_SUBTYPE_CURATED',
#   'value': 'ATRT'},
#  {'uniqueSampleKey': 'SUNiLTY3NTNBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzc6cHB0Y18yMDE5',
#   'sampleId': 'ICb-6753ATRT',
#   'patientId': 'P0137',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Cancer Type',
#    'description': 'Cancer Type',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '1',
#    'clinicalAttributeId': 'CANCER_TYPE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'CANCER_TYPE',
#   'value': 'Embryonal Tumor'},
#  {'uniqueSampleKey': 'SUNiLTY3NTNBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzc6cHB0Y18yMDE5',
#   'sampleId': 'ICb-6753ATRT',
#   'patientId': 'P0137',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Cancer Type Detailed',
#    'description': 'Cancer Type Detailed',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '1',
#    'clinicalAttributeId': 'CANCER_TYPE_DETAILED',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'CANCER_TYPE_DETAILED',
#   'value': 'Atypical Teratoid/Rhabdoid Tumor'},
#  {'uniqueSampleKey': 'SUNiLTY3NTNBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzc6cHB0Y18yMDE5',
#   'sampleId': 'ICb-6753ATRT',
#   'patientId': 'P0137',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'EXPRESSION',
#    'description': 'EXPRESSION',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '2',
#    'clinicalAttributeId': 'EXPRESSION',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'EXPRESSION',
#   'value': 'NO'},
#  {'uniqueSampleKey': 'SUNiLTY3NTNBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzc6cHB0Y18yMDE5',
#   'sampleId': 'ICb-6753ATRT',
#   'patientId': 'P0137',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Fraction Genome Altered',
#    'description': 'Fraction Genome Altered',
#    'datatype': 'NUMBER',
#    'patientAttribute': False,
#    'priority': '20',
#    'clinicalAttributeId': 'FRACTION_GENOME_ALTERED',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'FRACTION_GENOME_ALTERED',
#   'value': '0.0002'},
#  {'uniqueSampleKey': 'SUNiLTY3NTNBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzc6cHB0Y18yMDE5',
#   'sampleId': 'ICb-6753ATRT',
#   'patientId': 'P0137',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'HISTOPATHOLOGY',
#    'description': 'HISTOPATHOLOGY',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '3',
#    'clinicalAttributeId': 'HISTOPATHOLOGY',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'HISTOPATHOLOGY',
#   'value': 'SHH by pathology'},
#  {'uniqueSampleKey': 'SUNiLTY3NTNBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzc6cHB0Y18yMDE5',
#   'sampleId': 'ICb-6753ATRT',
#   'patientId': 'P0137',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Mutation Count',
#    'description': 'Mutation Count',
#    'datatype': 'NUMBER',
#    'patientAttribute': False,
#    'priority': '30',
#    'clinicalAttributeId': 'MUTATION_COUNT',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'MUTATION_COUNT',
#   'value': '127'},
#  {'uniqueSampleKey': 'SUNiLTY3NTNBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzc6cHB0Y18yMDE5',
#   'sampleId': 'ICb-6753ATRT',
#   'patientId': 'P0137',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Note',
#    'description': 'Note.',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '2',
#    'clinicalAttributeId': 'NOTE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'NOTE',
#   'value': 'Li, XN'},
#  {'uniqueSampleKey': 'SUNiLTY3NTNBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzc6cHB0Y18yMDE5',
#   'sampleId': 'ICb-6753ATRT',
#   'patientId': 'P0137',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Oncotree Code',
#    'description': 'Oncotree Code',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '1',
#    'clinicalAttributeId': 'ONCOTREE_CODE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'ONCOTREE_CODE',
#   'value': 'ATRT'},
#  {'uniqueSampleKey': 'SUNiLTY3NTNBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzc6cHB0Y18yMDE5',
#   'sampleId': 'ICb-6753ATRT',
#   'patientId': 'P0137',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'PHASE',
#    'description': 'PHASE',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '4',
#    'clinicalAttributeId': 'PHASE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'PHASE',
#   'value': 'Diagnosis'},
#  {'uniqueSampleKey': 'SUNiLTY3NTNBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzc6cHB0Y18yMDE5',
#   'sampleId': 'ICb-6753ATRT',
#   'patientId': 'P0137',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Site of Sample',
#    'description': 'Sample Site',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '4',
#    'clinicalAttributeId': 'SAMPLE_SITE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'SAMPLE_SITE',
#   'value': 'Cerebellum'},
#  {'uniqueSampleKey': 'SUNiLTY3NTNBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzc6cHB0Y18yMDE5',
#   'sampleId': 'ICb-6753ATRT',
#   'patientId': 'P0137',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'SPECIMEN_SITE',
#    'description': 'SPECIMEN_SITE',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '4',
#    'clinicalAttributeId': 'SITE_OF_SPECIMEN',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'SITE_OF_SPECIMEN',
#   'value': 'Cerebellum'},
#  {'uniqueSampleKey': 'SUNiLTY3NTNBVFJUOnBwdGNfMjAxOQ',
#   'uniquePatientKey': 'UDAxMzc6cHB0Y18yMDE5',
#   'sampleId': 'ICb-6753ATRT',
#   'patientId': 'P0137',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'TMB (nonsynonymous)',
#    'description': 'TMB (nonsynonymous)',
#    'datatype': 'NUMBER',
#    'patientAttribute': False,
#    'priority': '1',
#    'clinicalAttributeId': 'TMB_NONSYNONYMOUS',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'TMB_NONSYNONYMOUS',
#   'value': '4.233333333'},
#  {'uniqueSampleKey': 'SUNiLUwxMTE1QVRSVDpwcHRjXzIwMTk',
#   'uniquePatientKey': 'UDAxNDI6cHB0Y18yMDE5',
#   'sampleId': 'ICb-L1115ATRT',
#   'patientId': 'P0142',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Cancer Subtype Curated',
#    'description': 'Cancer Subtype Curated',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '5',
#    'clinicalAttributeId': 'CANCER_SUBTYPE_CURATED',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'CANCER_SUBTYPE_CURATED',
#   'value': 'ATRT'},
#  {'uniqueSampleKey': 'SUNiLUwxMTE1QVRSVDpwcHRjXzIwMTk',
#   'uniquePatientKey': 'UDAxNDI6cHB0Y18yMDE5',
#   'sampleId': 'ICb-L1115ATRT',
#   'patientId': 'P0142',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Cancer Type',
#    'description': 'Cancer Type',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '1',
#    'clinicalAttributeId': 'CANCER_TYPE',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'CANCER_TYPE',
#   'value': 'Embryonal Tumor'},
#  {'uniqueSampleKey': 'SUNiLUwxMTE1QVRSVDpwcHRjXzIwMTk',
#   'uniquePatientKey': 'UDAxNDI6cHB0Y18yMDE5',
#   'sampleId': 'ICb-L1115ATRT',
#   'patientId': 'P0142',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'Cancer Type Detailed',
#    'description': 'Cancer Type Detailed',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '1',
#    'clinicalAttributeId': 'CANCER_TYPE_DETAILED',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'CANCER_TYPE_DETAILED',
#   'value': 'Atypical Teratoid/Rhabdoid Tumor'},
#  {'uniqueSampleKey': 'SUNiLUwxMTE1QVRSVDpwcHRjXzIwMTk',
#   'uniquePatientKey': 'UDAxNDI6cHB0Y18yMDE5',
#   'sampleId': 'ICb-L1115ATRT',
#   'patientId': 'P0142',
#   'studyId': 'pptc_2019',
#   'clinicalAttribute': {'displayName': 'EXPRESSION',
#    'description': 'EXPRESSION',
#    'datatype': 'STRING',
#    'patientAttribute': False,
#    'priority': '2',
#    'clinicalAttributeId': 'EXPRESSION',
#    'studyId': 'pptc_2019'},
#   'patientAttribute': False,
#   'clinicalAttributeId': 'EXPRESSION',
#   'value': 'NO'},
#  ...]
