# %% [markdown]
# #### We have chosen to move away from the pyBioPortal program and move to using direct API calls for cBioPortal.
# The reason is that we are concerned about continued support of the pyBioPortal program and that the program is unaffiliated with this wrapper.

# %% [markdown]
# ### list all studies, via requests

# %%
import requests

BASE_URL = "https://www.cbioportal.org/api"
HEADERS = {"Accept": "application/json"}

study_id = "pptc_2019"

# %% [markdown]
# ### Get all studies

# %%
def get_studies():
    """Fetch available studies from cBioPortal"""
    url = f"{BASE_URL}/studies"
    response = requests.get(url, headers=HEADERS)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

# Example Usage
studies = get_studies()
# if studies:
#     for study in studies[:]:  # Print all studies
#         print(f"Study ID: {study['studyId']} - Name: {study['name']}")

# %% [markdown]
# ### List pediatric studies

# %%
peds = [
    "pptc_2019", #Pediatric Preclinical Testing Consortium  (CHOP, Cell Rep 2019)
    "mixed_pipseq_2017", #Pediatric Pan-cancer (Columbia U, Genome Med 2016)
    "es_dfarber_broad_2014", #Pediatric Ewing Sarcoma (DFCI, Cancer Discov 2014)
    "pediatric_dkfz_2017", #Pediatric Pan-Cancer (DKFZ, Nature 2017)
    "es_iocurie_2014", #Ewing Sarcoma (Institut Curie, Cancer Discov 2014)
    "pancan_mappyacts_2022", #Pediatric European MAPPYACTS Trial (Gustave Roussy, Cancer Discov 2022)
    "mbl_pcgp", #Medulloblastoma (PCGP, Nature 2012)
    "all_stjude_2015", #Acute Lymphoblastic Leukemia (St Jude, Nat Genet 2015)
    "all_stjude_2013", #Hypodiploid Acute Lymphoid Leukemia (St Jude, Nat Genet 2013)
    "all_phase2_target_2018_pub", #Pediatric Acute Lymphoid Leukemia - Phase II (TARGET, 2018)
    "aml_target_2018_pub", #Pediatric Acute Myeloid Leukemia (TARGET, 2018)
    "nbl_target_2018_pub", #Pediatric Neuroblastoma (TARGET, 2018)
    "rt_target_2018_pub", #Pediatric Rhabdoid Tumor (TARGET, 2018)
    "wt_target_2018_pub" #Pediatric Wilms' Tumor (TARGET, 2018)
]

# %% [markdown]
# ### Get pptc_2019 study info

# %%
def verify_study_exists(study_id):
    """Check if the study exists in cBioPortal."""
    url = f"{BASE_URL}/studies/{study_id}"
    response = requests.get(url, headers=HEADERS)

    print(f"Request URL: {url}")  
    print(f"Response Status Code: {response.status_code}")  

    if response.status_code == 200:
        print(f"Study {study_id} exists!")
        return response.json()
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

# Run the check
verify_study_exists("pptc_2019")
# Out:
# Request URL: https://www.cbioportal.org/api/studies/pptc_2019
# Response Status Code: 200
# Study pptc_2019 exists!
# {'name': 'Pediatric Preclinical Testing Consortium  (CHOP, Cell Rep 2019)',
#  'description': "Whole-exome sequencing of 261 patient derived xenografts (PDXs) samples from high-risk childhood cancers (with no matched normals). Website: <a href='http://www.ncipptc.org/'>PPTC</a>",
#  'publicStudy': True,
#  'pmid': '31693904',
#  'citation': 'Rotika et al. Cell Rep 2019',
#  'groups': 'PUBLIC',
#  'status': 0,
#  'importDate': '2024-12-21 20:50:55',
#  'allSampleCount': 261,
#  'sequencedSampleCount': 261,
#  'cnaSampleCount': 252,
#  'mrnaRnaSeqSampleCount': 244,
#  'mrnaRnaSeqV2SampleCount': 0,
#  'mrnaMicroarraySampleCount': 0,
#  'miRnaSampleCount': 0,
#  'methylationHm27SampleCount': 0,
#  'rppaSampleCount': 0,
#  'massSpectrometrySampleCount': 0,
#  'completeSampleCount': 222,
#  'readPermission': True,
#  'treatmentCount': 0,
#  'structuralVariantCount': 101,
#  'studyId': 'pptc_2019',
#  'cancerTypeId': 'mixed',
#  'cancerType': {'name': 'Mixed Cancer Types',
#   'dedicatedColor': 'Black',
#   'shortName': 'MIXED',
#   'parent': 'other',
#   'cancerTypeId': 'mixed'},
#  'referenceGenome': 'hg19'}

# %%
def get_study_info(study_id):
    """Fetch details for a specific study from cBioPortal"""
    url = f"{BASE_URL}/studies/{study_id}"
    response = requests.get(url, headers=HEADERS)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

# Example Usage
study_info = get_study_info(study_id)

if study_info:
    print(study_info)
# Out:
# {'name': 'Pediatric Preclinical Testing Consortium  (CHOP, Cell Rep 2019)', 'description': "Whole-exome sequencing of 261 patient derived xenografts (PDXs) samples from high-risk childhood cancers (with no matched normals). Website: <a href='http://www.ncipptc.org/'>PPTC</a>", 'publicStudy': True, 'pmid': '31693904', 'citation': 'Rotika et al. Cell Rep 2019', 'groups': 'PUBLIC', 'status': 0, 'importDate': '2024-12-21 20:50:55', 'allSampleCount': 261, 'sequencedSampleCount': 261, 'cnaSampleCount': 252, 'mrnaRnaSeqSampleCount': 244, 'mrnaRnaSeqV2SampleCount': 0, 'mrnaMicroarraySampleCount': 0, 'miRnaSampleCount': 0, 'methylationHm27SampleCount': 0, 'rppaSampleCount': 0, 'massSpectrometrySampleCount': 0, 'completeSampleCount': 222, 'readPermission': True, 'treatmentCount': 0, 'structuralVariantCount': 101, 'studyId': 'pptc_2019', 'cancerTypeId': 'mixed', 'cancerType': {'name': 'Mixed Cancer Types', 'dedicatedColor': 'Black', 'shortName': 'MIXED', 'parent': 'other', 'cancerTypeId': 'mixed'}, 'referenceGenome': 'hg19'}

# %% [markdown]
# ### Fetch clinical attributes

# %%
def get_clinical_attributes(study_id):
    """Fetch clinical attributes for a study from cBioPortal."""
    url = f"{BASE_URL}/clinical-attributes?studyId={study_id}"
    response = requests.get(url, headers=HEADERS)

    print(f"Request URL: {url}")  # Debugging
    print(f"Response Status Code: {response.status_code}")  # Debugging

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error {response.status_code}: {response.text}")  # Debugging
        return None

# Example Usage
clinical_attributes = get_clinical_attributes(study_id)

if clinical_attributes:
    print("Available Clinical Attributes:")
    for attr in clinical_attributes[:10]:
        print(f"- {attr['clinicalAttributeId']}: {attr['description']}")
# Out:
# Request URL: https://www.cbioportal.org/api/clinical-attributes?studyId=pptc_2019
# Response Status Code: 200
# Available Clinical Attributes:
# - ADJUVANT_CHEMO: Adjuvant Chemotherapy
# - ADJUVANT_TX: Adjuvant treatment.
# - AGE: Age at which a condition or disease was first diagnosed.
# - CANCER_TYPE: Cancer Type
# - CANCER_TYPE_DETAILED: Cancer Type Detailed
# - ER_STATUS_BY_IHC: breast carcinoma progesterone receptor status
# - FOLLOWUP_YEARS: Followup in years
# - FUSION_STATUS: Yes/No indicator of fusion status
# - GENOMIC_ALTERATIONS: Number of genomic alterations
# - IHC_HER2: IHC-HER2

# %% [markdown]
# ### Fetch data for attribute in study

# %%
def get_clinical_data(study_id, attribute_id, data_type="PATIENT"):
    """Fetch clinical data for a specific attribute from cBioPortal."""
    url = f"{BASE_URL}/studies/{study_id}/clinical-data/"
    response = requests.get(url, headers=HEADERS)

    print(f"Request URL: {url}")  # Debugging
    print(f"Response Status Code: {response.status_code}")  # Debugging

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error {response.status_code}: {response.text}")  # Debugging
        return None

# Example Usage
attribute_id = "AGE" 
clinical_data = get_clinical_data(study_id, attribute_id)

if clinical_data:
    print("Clinical Data Results:")
    for entry in clinical_data[:10]:  # Print first 10 results
        print(entry)
# Out:
# Request URL: https://www.cbioportal.org/api/studies/pptc_2019/clinical-data/
# Response Status Code: 200
# Clinical Data Results:
# {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ', 'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5', 'sampleId': 'ALL-03', 'patientId': 'P0002', 'studyId': 'pptc_2019', 'clinicalAttributeId': 'CANCER_SUBTYPE_CURATED', 'value': 'MLL-ALL'}
# {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ', 'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5', 'sampleId': 'ALL-03', 'patientId': 'P0002', 'studyId': 'pptc_2019', 'clinicalAttributeId': 'CANCER_TYPE', 'value': 'Leukemia'}
# {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ', 'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5', 'sampleId': 'ALL-03', 'patientId': 'P0002', 'studyId': 'pptc_2019', 'clinicalAttributeId': 'CANCER_TYPE_DETAILED', 'value': 'Acute Leukemias of Ambiguous Lineage'}
# {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ', 'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5', 'sampleId': 'ALL-03', 'patientId': 'P0002', 'studyId': 'pptc_2019', 'clinicalAttributeId': 'EXPRESSION', 'value': 'NO'}
# {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ', 'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5', 'sampleId': 'ALL-03', 'patientId': 'P0002', 'studyId': 'pptc_2019', 'clinicalAttributeId': 'FRACTION_GENOME_ALTERED', 'value': '0.0004'}
# {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ', 'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5', 'sampleId': 'ALL-03', 'patientId': 'P0002', 'studyId': 'pptc_2019', 'clinicalAttributeId': 'HISTOPATHOLOGY', 'value': 't(11;19), MLL-MLLT1'}
# {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ', 'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5', 'sampleId': 'ALL-03', 'patientId': 'P0002', 'studyId': 'pptc_2019', 'clinicalAttributeId': 'MUTATION_COUNT', 'value': '132'}
# {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ', 'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5', 'sampleId': 'ALL-03', 'patientId': 'P0002', 'studyId': 'pptc_2019', 'clinicalAttributeId': 'NOTE', 'value': 'Lock'}
# {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ', 'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5', 'sampleId': 'ALL-03', 'patientId': 'P0002', 'studyId': 'pptc_2019', 'clinicalAttributeId': 'ONCOTREE_CODE', 'value': 'ALAL'}
# {'uniqueSampleKey': 'QUxMLTAzOnBwdGNfMjAxOQ', 'uniquePatientKey': 'UDAwMDI6cHB0Y18yMDE5', 'sampleId': 'ALL-03', 'patientId': 'P0002', 'studyId': 'pptc_2019', 'clinicalAttributeId': 'PHASE', 'value': 'Diagnosis'}

# %% [markdown]
# ### Available molecular profiles

# %%
def get_molecular_profiles_for_study(study_id):
    """Fetch molecular profiles for a specific study and filter results."""
    url = f"{BASE_URL}/molecular-profiles"
    response = requests.get(url, headers=HEADERS)

    if response.status_code == 200:
        profiles = response.json()
        # Filter profiles for the specified study ID
        filtered_profiles = [profile for profile in profiles if profile['studyId'] == study_id]
        return filtered_profiles
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

# Example Usage
profiles = get_molecular_profiles_for_study(study_id)

if profiles:
    print(f"✅ Molecular Profiles for {study_id}:")
    for profile in profiles:
        print(f"- {profile['molecularProfileId']} ({profile['molecularAlterationType']})")
else:
    print(f"❌ No molecular profiles found for {study_id}.")
# Out:
# ✅ Molecular Profiles for pptc_2019:
# - pptc_2019_gistic (COPY_NUMBER_ALTERATION)
# - pptc_2019_mutations (MUTATION_EXTENDED)
# - pptc_2019_structural_variants (STRUCTURAL_VARIANT)
# - pptc_2019_rna_seq_mrna (MRNA_EXPRESSION)
# - pptc_2019_rna_seq_mrna_median_Zscores (MRNA_EXPRESSION)

# %% [markdown]
# ### Get mutations

# %%
## not returning mutations

def get_mutations(molecular_profile_id):
    """Fetch mutation data for a specific molecular profile"""
    url = f"{BASE_URL}/molecular-profiles/{molecular_profile_id}"
    response = requests.get(url, headers=HEADERS)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

# Example Usage
molecular_profile_id = "pptc_2019_mutations" 
mutations = get_mutations(molecular_profile_id)

if mutations:
    print("✅ Mutation Data:")
    for mutation in mutations:  # Print first 10 results
        print(mutation)
else:
    print("❌ No mutation data found.")
# Out:
# ✅ Mutation Data:
# molecularAlterationType
# datatype
# name
# description
# showProfileInAnalysisTab
# patientLevel
# molecularProfileId
# studyId
# study

# %% [markdown]
# ### Sample List ID

# %%
def get_sample_lists():
    """Fetch all samples lists"""
    url = f"{BASE_URL}/sample-lists"
    response = requests.get(url, headers=HEADERS)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

# Example Usage
all_sample_lists = get_sample_lists()

# for sample_lists in all_sample_lists:
#     print(sample_lists)
# Out:
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (93 samples)', 'sampleListId': 'all_stjude_2015_all', 'studyId': 'all_stjude_2015'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (93 samples)', 'sampleListId': 'all_stjude_2015_sequenced', 'studyId': 'all_stjude_2015'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (93 samples)', 'sampleListId': 'all_stjude_2015_sv', 'studyId': 'all_stjude_2015'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (44 samples)', 'sampleListId': 'all_stjude_2013_all', 'studyId': 'all_stjude_2013'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (44 samples)', 'sampleListId': 'all_stjude_2013_sequenced', 'studyId': 'all_stjude_2013'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (28 samples)', 'sampleListId': 'acyc_fmi_2014_all', 'studyId': 'acyc_fmi_2014'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (28 samples)', 'sampleListId': 'acyc_fmi_2014_cna', 'studyId': 'acyc_fmi_2014'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (15 samples)', 'sampleListId': 'acyc_fmi_2014_cnaseq', 'studyId': 'acyc_fmi_2014'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (28 samples)', 'sampleListId': 'acyc_fmi_2014_sequenced', 'studyId': 'acyc_fmi_2014'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (25 samples)', 'sampleListId': 'acyc_jhu_2016_all', 'studyId': 'acyc_jhu_2016'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (25 samples)', 'sampleListId': 'acyc_jhu_2016_sequenced', 'studyId': 'acyc_jhu_2016'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (25 samples)', 'sampleListId': 'acyc_jhu_2016_sv', 'studyId': 'acyc_jhu_2016'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (102 samples)', 'sampleListId': 'acyc_mda_2015_all', 'studyId': 'acyc_mda_2015'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (65 samples)', 'sampleListId': 'acyc_mda_2015_sequenced', 'studyId': 'acyc_mda_2015'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (102 samples)', 'sampleListId': 'acyc_mda_2015_sv', 'studyId': 'acyc_mda_2015'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (10 samples)', 'sampleListId': 'acyc_mgh_2016_all', 'studyId': 'acyc_mgh_2016'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (10 samples)', 'sampleListId': 'acyc_mgh_2016_sequenced', 'studyId': 'acyc_mgh_2016'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (10 samples)', 'sampleListId': 'acyc_mgh_2016_sv', 'studyId': 'acyc_mgh_2016'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (24 samples)', 'sampleListId': 'acyc_sanger_2013_all', 'studyId': 'acyc_sanger_2013'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (24 samples)', 'sampleListId': 'acyc_sanger_2013_sequenced', 'studyId': 'acyc_sanger_2013'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (73 samples)', 'sampleListId': 'all_stjude_2016_all', 'studyId': 'all_stjude_2016'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (73 samples)', 'sampleListId': 'all_stjude_2016_sequenced', 'studyId': 'all_stjude_2016'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (273 samples)', 'sampleListId': 'appendiceal_msk_2022_all', 'studyId': 'appendiceal_msk_2022'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (273 samples)', 'sampleListId': 'appendiceal_msk_2022_cna', 'studyId': 'appendiceal_msk_2022'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (273 samples)', 'sampleListId': 'appendiceal_msk_2022_cnaseq', 'studyId': 'appendiceal_msk_2022'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (273 samples)', 'sampleListId': 'appendiceal_msk_2022_sequenced', 'studyId': 'appendiceal_msk_2022'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (273 samples)', 'sampleListId': 'appendiceal_msk_2022_sv', 'studyId': 'appendiceal_msk_2022'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (34 samples)', 'sampleListId': 'blca_plasmacytoid_mskcc_2016_all', 'studyId': 'blca_plasmacytoid_mskcc_2016'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (33 samples)', 'sampleListId': 'blca_plasmacytoid_mskcc_2016_cna', 'studyId': 'blca_plasmacytoid_mskcc_2016'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (33 samples)', 'sampleListId': 'blca_plasmacytoid_mskcc_2016_cnaseq', 'studyId': 'blca_plasmacytoid_mskcc_2016'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (34 samples)', 'sampleListId': 'blca_plasmacytoid_mskcc_2016_sequenced', 'studyId': 'blca_plasmacytoid_mskcc_2016'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (34 samples)', 'sampleListId': 'blca_plasmacytoid_mskcc_2016_sv', 'studyId': 'blca_plasmacytoid_mskcc_2016'}
# {'category': 'all_cases_in_study', 'name': 'All Tumors', 'description': 'All tumor samples (293 samples)', 'sampleListId': 'bcc_unige_2016_all', 'studyId': 'bcc_unige_2016'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Sequenced Tumors', 'description': 'All (Next-Gen) sequenced samples (293 samples)', 'sampleListId': 'bcc_unige_2016_sequenced', 'studyId': 'bcc_unige_2016'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (103 samples)', 'sampleListId': 'brca_broad_all', 'studyId': 'brca_broad'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (103 samples)', 'sampleListId': 'brca_broad_sequenced', 'studyId': 'brca_broad'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (109 samples)', 'sampleListId': 'blca_mskcc_solit_2014_all', 'studyId': 'blca_mskcc_solit_2014'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (109 samples)', 'sampleListId': 'blca_mskcc_solit_2014_cna', 'studyId': 'blca_mskcc_solit_2014'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (109 samples)', 'sampleListId': 'blca_mskcc_solit_2014_cnaseq', 'studyId': 'blca_mskcc_solit_2014'}
# {'category': 'all_cases_with_log2_cna_data', 'name': 'Samples with log2 copy-number data', 'description': 'Samples with log2 copy-number data (109 samples)', 'sampleListId': 'blca_mskcc_solit_2014_log2CNA', 'studyId': 'blca_mskcc_solit_2014'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (109 samples)', 'sampleListId': 'blca_mskcc_solit_2014_sequenced', 'studyId': 'blca_mskcc_solit_2014'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (105 samples)', 'sampleListId': 'blca_nmibc_2017_all', 'studyId': 'blca_nmibc_2017'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (105 samples)', 'sampleListId': 'blca_nmibc_2017_cna', 'studyId': 'blca_nmibc_2017'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (105 samples)', 'sampleListId': 'blca_nmibc_2017_cnaseq', 'studyId': 'blca_nmibc_2017'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (105 samples)', 'sampleListId': 'blca_nmibc_2017_sequenced', 'studyId': 'blca_nmibc_2017'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (105 samples)', 'sampleListId': 'blca_nmibc_2017_sv', 'studyId': 'blca_nmibc_2017'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (22 samples)', 'sampleListId': 'bfn_duke_nus_2015_all', 'studyId': 'bfn_duke_nus_2015'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (22 samples)', 'sampleListId': 'bfn_duke_nus_2015_sequenced', 'studyId': 'bfn_duke_nus_2015'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (5 samples)', 'sampleListId': 'brca_jup_msk_2020_all', 'studyId': 'brca_jup_msk_2020'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (5 samples)', 'sampleListId': 'brca_jup_msk_2020_sequenced', 'studyId': 'brca_jup_msk_2020'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (145 samples)', 'sampleListId': 'brca_mapk_hp_msk_2021_all', 'studyId': 'brca_mapk_hp_msk_2021'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (145 samples)', 'sampleListId': 'brca_mapk_hp_msk_2021_cna', 'studyId': 'brca_mapk_hp_msk_2021'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (145 samples)', 'sampleListId': 'brca_mapk_hp_msk_2021_cnaseq', 'studyId': 'brca_mapk_hp_msk_2021'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (145 samples)', 'sampleListId': 'brca_mapk_hp_msk_2021_sequenced', 'studyId': 'brca_mapk_hp_msk_2021'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (145 samples)', 'sampleListId': 'brca_mapk_hp_msk_2021_sv', 'studyId': 'brca_mapk_hp_msk_2021'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (5 samples)', 'sampleListId': 'brca_hta9_htan_2022_all', 'studyId': 'brca_hta9_htan_2022'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (5 samples)', 'sampleListId': 'brca_hta9_htan_2022_cna', 'studyId': 'brca_hta9_htan_2022'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (5 samples)', 'sampleListId': 'brca_hta9_htan_2022_cnaseq', 'studyId': 'brca_hta9_htan_2022'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (5 samples)', 'sampleListId': 'brca_hta9_htan_2022_sequenced', 'studyId': 'brca_hta9_htan_2022'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (36 samples)', 'sampleListId': 'biliary_tract_summit_2022_all', 'studyId': 'biliary_tract_summit_2022'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (34 samples)', 'sampleListId': 'biliary_tract_summit_2022_cna', 'studyId': 'biliary_tract_summit_2022'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (34 samples)', 'sampleListId': 'biliary_tract_summit_2022_cnaseq', 'studyId': 'biliary_tract_summit_2022'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (34 samples)', 'sampleListId': 'biliary_tract_summit_2022_sequenced', 'studyId': 'biliary_tract_summit_2022'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (180 samples)', 'sampleListId': 'bowel_colitis_msk_2022_all', 'studyId': 'bowel_colitis_msk_2022'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (166 samples)', 'sampleListId': 'bowel_colitis_msk_2022_cna', 'studyId': 'bowel_colitis_msk_2022'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (166 samples)', 'sampleListId': 'bowel_colitis_msk_2022_cnaseq', 'studyId': 'bowel_colitis_msk_2022'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (166 samples)', 'sampleListId': 'bowel_colitis_msk_2022_sequenced', 'studyId': 'bowel_colitis_msk_2022'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples with SV data (166 samples)', 'sampleListId': 'bowel_colitis_msk_2022_sv', 'studyId': 'bowel_colitis_msk_2022'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (130 samples)', 'sampleListId': 'bladder_columbia_msk_2018_all', 'studyId': 'bladder_columbia_msk_2018'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (130 samples)', 'sampleListId': 'bladder_columbia_msk_2018_cna', 'studyId': 'bladder_columbia_msk_2018'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (130 samples)', 'sampleListId': 'bladder_columbia_msk_2018_cnaseq', 'studyId': 'bladder_columbia_msk_2018'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (130 samples)', 'sampleListId': 'bladder_columbia_msk_2018_sequenced', 'studyId': 'bladder_columbia_msk_2018'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (526 samples)', 'sampleListId': 'bladder_msk_2023_all', 'studyId': 'bladder_msk_2023'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (526 samples)', 'sampleListId': 'bladder_msk_2023_cna', 'studyId': 'bladder_msk_2023'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (526 samples)', 'sampleListId': 'bladder_msk_2023_cnaseq', 'studyId': 'bladder_msk_2023'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (526 samples)', 'sampleListId': 'bladder_msk_2023_sequenced', 'studyId': 'bladder_msk_2023'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples with SV data (526 samples)', 'sampleListId': 'bladder_msk_2023_sv', 'studyId': 'bladder_msk_2023'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (322 samples)', 'sampleListId': 'bm_nsclc_mskcc_2023_all', 'studyId': 'bm_nsclc_mskcc_2023'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (322 samples)', 'sampleListId': 'bm_nsclc_mskcc_2023_cna', 'studyId': 'bm_nsclc_mskcc_2023'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (322 samples)', 'sampleListId': 'bm_nsclc_mskcc_2023_cnaseq', 'studyId': 'bm_nsclc_mskcc_2023'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (322 samples)', 'sampleListId': 'bm_nsclc_mskcc_2023_sequenced', 'studyId': 'bm_nsclc_mskcc_2023'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'Samples with SV data', 'sampleListId': 'bm_nsclc_mskcc_2023_sv', 'studyId': 'bm_nsclc_mskcc_2023'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (69 samples)', 'sampleListId': 'brca_fuscc_2020_all', 'studyId': 'brca_fuscc_2020'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (69 samples)', 'sampleListId': 'brca_fuscc_2020_sequenced', 'studyId': 'brca_fuscc_2020'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (1918 samples)', 'sampleListId': 'breast_msk_2018_all', 'studyId': 'breast_msk_2018'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (1918 samples)', 'sampleListId': 'breast_msk_2018_cna', 'studyId': 'breast_msk_2018'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (1918 samples)', 'sampleListId': 'breast_msk_2018_cnaseq', 'studyId': 'breast_msk_2018'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (1918 samples)', 'sampleListId': 'breast_msk_2018_sequenced', 'studyId': 'breast_msk_2018'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (1918 samples)', 'sampleListId': 'breast_msk_2018_sv', 'studyId': 'breast_msk_2018'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (70 samples)', 'sampleListId': 'brca_mskcc_2019_all', 'studyId': 'brca_mskcc_2019'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (70 samples)', 'sampleListId': 'brca_mskcc_2019_cna', 'studyId': 'brca_mskcc_2019'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (70 samples)', 'sampleListId': 'brca_mskcc_2019_cnaseq', 'studyId': 'brca_mskcc_2019'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (70 samples)', 'sampleListId': 'brca_mskcc_2019_sequenced', 'studyId': 'brca_mskcc_2019'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (141 samples)', 'sampleListId': 'breast_alpelisib_2020_all', 'studyId': 'breast_alpelisib_2020'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (39 samples)', 'sampleListId': 'breast_alpelisib_2020_cna', 'studyId': 'breast_alpelisib_2020'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (39 samples)', 'sampleListId': 'breast_alpelisib_2020_cnaseq', 'studyId': 'breast_alpelisib_2020'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (141 samples)', 'sampleListId': 'breast_alpelisib_2020_sequenced', 'studyId': 'breast_alpelisib_2020'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (141 samples)', 'sampleListId': 'breast_alpelisib_2020_sv', 'studyId': 'breast_alpelisib_2020'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (248 samples)', 'sampleListId': 'cfdna_msk_2019_all', 'studyId': 'cfdna_msk_2019'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (248 samples)', 'sampleListId': 'cfdna_msk_2019_sequenced', 'studyId': 'cfdna_msk_2019'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (35 samples)', 'sampleListId': 'ccrcc_dfci_2019_all', 'studyId': 'ccrcc_dfci_2019'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (35 samples)', 'sampleListId': 'ccrcc_dfci_2019_sequenced', 'studyId': 'ccrcc_dfci_2019'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (1365 samples)', 'sampleListId': 'breast_ink4_msk_2021_all', 'studyId': 'breast_ink4_msk_2021'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (1365 samples)', 'sampleListId': 'breast_ink4_msk_2021_cna', 'studyId': 'breast_ink4_msk_2021'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (1365 samples)', 'sampleListId': 'breast_ink4_msk_2021_cnaseq', 'studyId': 'breast_ink4_msk_2021'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (1365 samples)', 'sampleListId': 'breast_ink4_msk_2021_sequenced', 'studyId': 'breast_ink4_msk_2021'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (1365 samples)', 'sampleListId': 'breast_ink4_msk_2021_sv', 'studyId': 'breast_ink4_msk_2021'}
# {'category': 'all_cases_in_study', 'name': 'All Tumors', 'description': 'All tumor samples', 'sampleListId': 'brca_pareja_msk_2020_all', 'studyId': 'brca_pareja_msk_2020'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Sequenced Tumors', 'description': 'All sequenced tumors', 'sampleListId': 'brca_pareja_msk_2020_sequenced', 'studyId': 'brca_pareja_msk_2020'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (177 samples)', 'sampleListId': 'cervix_msk_2023_all', 'studyId': 'cervix_msk_2023'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (177 samples)', 'sampleListId': 'cervix_msk_2023_cna', 'studyId': 'cervix_msk_2023'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (177 samples)', 'sampleListId': 'cervix_msk_2023_cnaseq', 'studyId': 'cervix_msk_2023'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (177 samples)', 'sampleListId': 'cervix_msk_2023_sequenced', 'studyId': 'cervix_msk_2023'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples with SV data (177 samples)', 'sampleListId': 'cervix_msk_2023_sv', 'studyId': 'cervix_msk_2023'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (40 samples)', 'sampleListId': 'chol_jhu_2013_all', 'studyId': 'chol_jhu_2013'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (40 samples)', 'sampleListId': 'chol_jhu_2013_sequenced', 'studyId': 'chol_jhu_2013'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (15 samples)', 'sampleListId': 'chol_nccs_2013_all', 'studyId': 'chol_nccs_2013'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (15 samples)', 'sampleListId': 'chol_nccs_2013_sequenced', 'studyId': 'chol_nccs_2013'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (8 samples)', 'sampleListId': 'chol_nus_2012_all', 'studyId': 'chol_nus_2012'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (8 samples)', 'sampleListId': 'chol_nus_2012_sequenced', 'studyId': 'chol_nus_2012'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (138 samples)', 'sampleListId': 'coadread_mskcc_all', 'studyId': 'coadread_mskcc'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (138 samples)', 'sampleListId': 'coadread_mskcc_sequenced', 'studyId': 'coadread_mskcc'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (105 samples)', 'sampleListId': 'cllsll_icgc_2011_all', 'studyId': 'cllsll_icgc_2011'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (105 samples)', 'sampleListId': 'cllsll_icgc_2011_sequenced', 'studyId': 'cllsll_icgc_2011'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (29 samples)', 'sampleListId': 'coad_caseccc_2015_all', 'studyId': 'coad_caseccc_2015'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (29 samples)', 'sampleListId': 'coad_caseccc_2015_sequenced', 'studyId': 'coad_caseccc_2015'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (195 samples)', 'sampleListId': 'chol_msk_2018_all', 'studyId': 'chol_msk_2018'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (195 samples)', 'sampleListId': 'chol_msk_2018_cna', 'studyId': 'chol_msk_2018'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (195 samples)', 'sampleListId': 'chol_msk_2018_cnaseq', 'studyId': 'chol_msk_2018'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (195 samples)', 'sampleListId': 'chol_msk_2018_sequenced', 'studyId': 'chol_msk_2018'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (195 samples)', 'sampleListId': 'chol_msk_2018_sv', 'studyId': 'chol_msk_2018'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (489 samples)', 'sampleListId': 'chol_icgc_2017_all', 'studyId': 'chol_icgc_2017'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (417 samples)', 'sampleListId': 'chol_icgc_2017_sequenced', 'studyId': 'chol_icgc_2017'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (22 samples)', 'sampleListId': 'coadread_mskresistance_2022_all', 'studyId': 'coadread_mskresistance_2022'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (22 samples)', 'sampleListId': 'coadread_mskresistance_2022_cna', 'studyId': 'coadread_mskresistance_2022'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (22 samples)', 'sampleListId': 'coadread_mskresistance_2022_cnaseq', 'studyId': 'coadread_mskresistance_2022'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (22 samples)', 'sampleListId': 'coadread_mskresistance_2022_sequenced', 'studyId': 'coadread_mskresistance_2022'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples with SV data (22 samples)', 'sampleListId': 'coadread_mskresistance_2022_sv', 'studyId': 'coadread_mskresistance_2022'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (29 samples)', 'sampleListId': 'cscc_dfarber_2015_all', 'studyId': 'cscc_dfarber_2015'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (29 samples)', 'sampleListId': 'cscc_dfarber_2015_sequenced', 'studyId': 'cscc_dfarber_2015'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (42 samples)', 'sampleListId': 'ctcl_columbia_2015_all', 'studyId': 'ctcl_columbia_2015'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (42 samples)', 'sampleListId': 'ctcl_columbia_2015_sequenced', 'studyId': 'ctcl_columbia_2015'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (1134 samples)', 'sampleListId': 'crc_msk_2017_all', 'studyId': 'crc_msk_2017'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (1134 samples)', 'sampleListId': 'crc_msk_2017_cna', 'studyId': 'crc_msk_2017'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (1134 samples)', 'sampleListId': 'crc_msk_2017_cnaseq', 'studyId': 'crc_msk_2017'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (1134 Samples)', 'sampleListId': 'crc_msk_2017_sequenced', 'studyId': 'crc_msk_2017'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (1134 samples)', 'sampleListId': 'crc_msk_2017_sv', 'studyId': 'crc_msk_2017'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (1516 samples)', 'sampleListId': 'crc_eo_2020_all', 'studyId': 'crc_eo_2020'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (1516 samples)', 'sampleListId': 'crc_eo_2020_cna', 'studyId': 'crc_eo_2020'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (1516 samples)', 'sampleListId': 'crc_eo_2020_cnaseq', 'studyId': 'crc_eo_2020'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (1516 samples)', 'sampleListId': 'crc_eo_2020_sequenced', 'studyId': 'crc_eo_2020'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (1516 samples)', 'sampleListId': 'crc_eo_2020_sv', 'studyId': 'crc_eo_2020'}
# {'category': 'all_cases_in_study', 'name': 'All Tumors', 'description': 'All tumor samples (471 samples)', 'sampleListId': 'crc_apc_impact_2020_all', 'studyId': 'crc_apc_impact_2020'}
# {'category': 'all_cases_with_cna_data', 'name': 'Tumor Samples with CNA data', 'description': 'All tumors with CNA data (471 samples)', 'sampleListId': 'crc_apc_impact_2020_cna', 'studyId': 'crc_apc_impact_2020'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Tumor Samples with sequencing and CNA data', 'description': 'All tumor samples that have CNA and sequencing data (471 samples)', 'sampleListId': 'crc_apc_impact_2020_cnaseq', 'studyId': 'crc_apc_impact_2020'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Sequenced Tumors', 'description': 'All (Next-Gen) sequenced samples (471 samples)', 'sampleListId': 'crc_apc_impact_2020_sequenced', 'studyId': 'crc_apc_impact_2020'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (471 samples)', 'sampleListId': 'crc_apc_impact_2020_sv', 'studyId': 'crc_apc_impact_2020'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (64 samples)', 'sampleListId': 'crc_nigerian_2020_all', 'studyId': 'crc_nigerian_2020'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (64 samples)', 'sampleListId': 'crc_nigerian_2020_cna', 'studyId': 'crc_nigerian_2020'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (64 samples)', 'sampleListId': 'crc_nigerian_2020_cnaseq', 'studyId': 'crc_nigerian_2020'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (64 samples)', 'sampleListId': 'crc_nigerian_2020_sequenced', 'studyId': 'crc_nigerian_2020'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (47 samples)', 'sampleListId': 'crc_dd_2022_all', 'studyId': 'crc_dd_2022'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (47 samples)', 'sampleListId': 'crc_dd_2022_cna', 'studyId': 'crc_dd_2022'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (47 samples)', 'sampleListId': 'crc_dd_2022_cnaseq', 'studyId': 'crc_dd_2022'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (47 samples)', 'sampleListId': 'crc_dd_2022_sequenced', 'studyId': 'crc_dd_2022'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (47 samples)', 'sampleListId': 'crc_dd_2022_sv', 'studyId': 'crc_dd_2022'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (73 samples)', 'sampleListId': 'difg_msk_2023_all', 'studyId': 'difg_msk_2023'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (73 samples)', 'sampleListId': 'difg_msk_2023_cna', 'studyId': 'difg_msk_2023'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (73 samples)', 'sampleListId': 'difg_msk_2023_cnaseq', 'studyId': 'difg_msk_2023'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (73 samples)', 'sampleListId': 'difg_msk_2023_sequenced', 'studyId': 'difg_msk_2023'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples with SV data (73 samples)', 'sampleListId': 'difg_msk_2023_sv', 'studyId': 'difg_msk_2023'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (139 samples)', 'sampleListId': 'escc_ucla_2014_all', 'studyId': 'escc_ucla_2014'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (139 samples)', 'sampleListId': 'escc_ucla_2014_sequenced', 'studyId': 'escc_ucla_2014'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (151 samples)', 'sampleListId': 'esca_broad_all', 'studyId': 'esca_broad'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (151 samples)', 'sampleListId': 'esca_broad_sequenced', 'studyId': 'esca_broad'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (180 samples)', 'sampleListId': 'gct_msk_2016_all', 'studyId': 'gct_msk_2016'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (180 samples)', 'sampleListId': 'gct_msk_2016_cna', 'studyId': 'gct_msk_2016'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (180 samples)', 'sampleListId': 'gct_msk_2016_cnaseq', 'studyId': 'gct_msk_2016'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (180 samples)', 'sampleListId': 'gct_msk_2016_sequenced', 'studyId': 'gct_msk_2016'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (180 samples)', 'sampleListId': 'gct_msk_2016_sv', 'studyId': 'gct_msk_2016'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (341 samples)', 'sampleListId': 'egc_msk_2017_all', 'studyId': 'egc_msk_2017'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (341 samples)', 'sampleListId': 'egc_msk_2017_cna', 'studyId': 'egc_msk_2017'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (341 samples)', 'sampleListId': 'egc_msk_2017_cnaseq', 'studyId': 'egc_msk_2017'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (341 samples)', 'sampleListId': 'egc_msk_2017_sequenced', 'studyId': 'egc_msk_2017'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (341 samples)', 'sampleListId': 'egc_msk_2017_sv', 'studyId': 'egc_msk_2017'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (127 samples)', 'sampleListId': 'hcc_mskimpact_2018_all', 'studyId': 'hcc_mskimpact_2018'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (127 samples)', 'sampleListId': 'hcc_mskimpact_2018_cna', 'studyId': 'hcc_mskimpact_2018'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (127 samples)', 'sampleListId': 'hcc_mskimpact_2018_cnaseq', 'studyId': 'hcc_mskimpact_2018'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (127 samples)', 'sampleListId': 'hcc_mskimpact_2018_sequenced', 'studyId': 'hcc_mskimpact_2018'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (127 samples)', 'sampleListId': 'hcc_mskimpact_2018_sv', 'studyId': 'hcc_mskimpact_2018'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (19 samples)', 'sampleListId': 'hcc_msk_venturaa_2018_all', 'studyId': 'hcc_msk_venturaa_2018'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (19 samples)', 'sampleListId': 'hcc_msk_venturaa_2018_cna', 'studyId': 'hcc_msk_venturaa_2018'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (19 samples)', 'sampleListId': 'hcc_msk_venturaa_2018_cnaseq', 'studyId': 'hcc_msk_venturaa_2018'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (19 samples)', 'sampleListId': 'hcc_msk_venturaa_2018_sequenced', 'studyId': 'hcc_msk_venturaa_2018'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (1001 samples)', 'sampleListId': 'dlbcl_duke_2017_all', 'studyId': 'dlbcl_duke_2017'}
# {'category': 'all_cases_with_log2_cna_data', 'name': 'Samples with log2 copy-number data', 'description': 'Samples with log2 copy-number data (1001 samples)', 'sampleListId': 'dlbcl_duke_2017_log2CNA', 'studyId': 'dlbcl_duke_2017'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (1001 samples)', 'sampleListId': 'dlbcl_duke_2017_sequenced', 'studyId': 'dlbcl_duke_2017'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (1004 samples)', 'sampleListId': 'glioma_mskcc_2019_all', 'studyId': 'glioma_mskcc_2019'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (1004 samples)', 'sampleListId': 'glioma_mskcc_2019_cna', 'studyId': 'glioma_mskcc_2019'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (1004 samples)', 'sampleListId': 'glioma_mskcc_2019_cnaseq', 'studyId': 'glioma_mskcc_2019'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (1004 samples)', 'sampleListId': 'glioma_mskcc_2019_sequenced', 'studyId': 'glioma_mskcc_2019'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (1004 samples)', 'sampleListId': 'glioma_mskcc_2019_sv', 'studyId': 'glioma_mskcc_2019'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (91 samples)', 'sampleListId': 'glioma_msk_2018_all', 'studyId': 'glioma_msk_2018'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (91 samples)', 'sampleListId': 'glioma_msk_2018_cna', 'studyId': 'glioma_msk_2018'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (91 samples)', 'sampleListId': 'glioma_msk_2018_cnaseq', 'studyId': 'glioma_msk_2018'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (91 samples)', 'sampleListId': 'glioma_msk_2018_sequenced', 'studyId': 'glioma_msk_2018'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (91 samples)', 'sampleListId': 'glioma_msk_2018_sv', 'studyId': 'glioma_msk_2018'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (103 samples)', 'sampleListId': 'gbc_msk_2018_all', 'studyId': 'gbc_msk_2018'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (103 samples)', 'sampleListId': 'gbc_msk_2018_cna', 'studyId': 'gbc_msk_2018'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (97 samples)', 'sampleListId': 'gbc_msk_2018_cnaseq', 'studyId': 'gbc_msk_2018'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (97 samples)', 'sampleListId': 'gbc_msk_2018_sequenced', 'studyId': 'gbc_msk_2018'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (97 samples)', 'sampleListId': 'gbc_msk_2018_sv', 'studyId': 'gbc_msk_2018'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (42 samples)', 'sampleListId': 'gbm_columbia_2019_all', 'studyId': 'gbm_columbia_2019'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (32 samples)', 'sampleListId': 'gbm_columbia_2019_sequenced', 'studyId': 'gbm_columbia_2019'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (21 samples)', 'sampleListId': 'gct_msk_2020_all', 'studyId': 'gct_msk_2020'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (21 samples)', 'sampleListId': 'gct_msk_2020_sequenced', 'studyId': 'gct_msk_2020'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (487 samples)', 'sampleListId': 'egc_mskcc_2020_all', 'studyId': 'egc_mskcc_2020'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (487 samples)', 'sampleListId': 'egc_mskcc_2020_cna', 'studyId': 'egc_mskcc_2020'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (487 samples)', 'sampleListId': 'egc_mskcc_2020_cnaseq', 'studyId': 'egc_mskcc_2020'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (487 samples)', 'sampleListId': 'egc_mskcc_2020_sequenced', 'studyId': 'egc_mskcc_2020'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (487 samples)', 'sampleListId': 'egc_mskcc_2020_sv', 'studyId': 'egc_mskcc_2020'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (237 samples)', 'sampleListId': 'egc_msk_tp53_ccr_2022_all', 'studyId': 'egc_msk_tp53_ccr_2022'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (237 samples)', 'sampleListId': 'egc_msk_tp53_ccr_2022_cna', 'studyId': 'egc_msk_tp53_ccr_2022'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (237 samples)', 'sampleListId': 'egc_msk_tp53_ccr_2022_cnaseq', 'studyId': 'egc_msk_tp53_ccr_2022'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (237 samples)', 'sampleListId': 'egc_msk_tp53_ccr_2022_sequenced', 'studyId': 'egc_msk_tp53_ccr_2022'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples with SV data (237 samples)', 'sampleListId': 'egc_msk_tp53_ccr_2022_sv', 'studyId': 'egc_msk_tp53_ccr_2022'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (244 samples)', 'sampleListId': 'gbc_mskcc_2022_all', 'studyId': 'gbc_mskcc_2022'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (244 samples)', 'sampleListId': 'gbc_mskcc_2022_cna', 'studyId': 'gbc_mskcc_2022'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (244 samples)', 'sampleListId': 'gbc_mskcc_2022_cnaseq', 'studyId': 'gbc_mskcc_2022'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (244 samples)', 'sampleListId': 'gbc_mskcc_2022_sequenced', 'studyId': 'gbc_mskcc_2022'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (244 samples)', 'sampleListId': 'gbc_mskcc_2022_sv', 'studyId': 'gbc_mskcc_2022'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (499 samples)', 'sampleListId': 'gist_msk_2022_all', 'studyId': 'gist_msk_2022'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (499 samples)', 'sampleListId': 'gist_msk_2022_cna', 'studyId': 'gist_msk_2022'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (499 samples)', 'sampleListId': 'gist_msk_2022_cnaseq', 'studyId': 'gist_msk_2022'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (499 samples)', 'sampleListId': 'gist_msk_2022_sequenced', 'studyId': 'gist_msk_2022'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples with SV data (499 samples)', 'sampleListId': 'gist_msk_2022_sv', 'studyId': 'gist_msk_2022'}
# ...
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (80 samples)', 'sampleListId': 'uvm_tcga_pan_can_atlas_2018_all', 'studyId': 'uvm_tcga_pan_can_atlas_2018'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (80 samples)', 'sampleListId': 'uvm_tcga_pan_can_atlas_2018_cna', 'studyId': 'uvm_tcga_pan_can_atlas_2018'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (80 samples)', 'sampleListId': 'uvm_tcga_pan_can_atlas_2018_cnaseq', 'studyId': 'uvm_tcga_pan_can_atlas_2018'}
# {'category': 'all_cases_with_mutation_and_cna_and_mrna_data', 'name': 'Complete samples', 'description': 'Samples with mutation, CNA and expression data (80 samples)', 'sampleListId': 'uvm_tcga_pan_can_atlas_2018_3way_complete', 'studyId': 'uvm_tcga_pan_can_atlas_2018'}
# {'category': 'all_cases_with_log2_cna_data', 'name': 'Samples with log2 copy-number data', 'description': 'Samples with log2 copy-number data (80 samples)', 'sampleListId': 'uvm_tcga_pan_can_atlas_2018_log2CNA', 'studyId': 'uvm_tcga_pan_can_atlas_2018'}
# {'category': 'all_cases_with_rppa_data', 'name': 'Samples with protein data (RPPA)', 'description': 'Samples with protein data (RPPA) (12 samples)', 'sampleListId': 'uvm_tcga_pan_can_atlas_2018_rppa', 'studyId': 'uvm_tcga_pan_can_atlas_2018'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (80 samples)', 'sampleListId': 'uvm_tcga_pan_can_atlas_2018_sequenced', 'studyId': 'uvm_tcga_pan_can_atlas_2018'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples', 'sampleListId': 'uvm_tcga_pan_can_atlas_2018_sv', 'studyId': 'uvm_tcga_pan_can_atlas_2018'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (348 samples)', 'sampleListId': 'coad_silu_2022_all', 'studyId': 'coad_silu_2022'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data', 'sampleListId': 'coad_silu_2022_cna', 'studyId': 'coad_silu_2022'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data', 'sampleListId': 'coad_silu_2022_cnaseq', 'studyId': 'coad_silu_2022'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data', 'sampleListId': 'coad_silu_2022_sequenced', 'studyId': 'coad_silu_2022'}
# {'category': 'all_cases_with_mrna_rnaseq_data', 'name': 'Samples with mRNA data (RNA Seq V2)', 'description': 'Samples with mRNA expression data (78 samples)', 'sampleListId': 'acc_tcga_pan_can_atlas_2018_rna_seq_v2_mrna', 'studyId': 'acc_tcga_pan_can_atlas_2018'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (92 samples)', 'sampleListId': 'acc_tcga_pan_can_atlas_2018_all', 'studyId': 'acc_tcga_pan_can_atlas_2018'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (89 samples)', 'sampleListId': 'acc_tcga_pan_can_atlas_2018_cna', 'studyId': 'acc_tcga_pan_can_atlas_2018'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (89 samples)', 'sampleListId': 'acc_tcga_pan_can_atlas_2018_cnaseq', 'studyId': 'acc_tcga_pan_can_atlas_2018'}
# {'category': 'all_cases_with_mutation_and_cna_and_mrna_data', 'name': 'Complete samples', 'description': 'Samples with mutation, CNA and expression data (76 samples)', 'sampleListId': 'acc_tcga_pan_can_atlas_2018_3way_complete', 'studyId': 'acc_tcga_pan_can_atlas_2018'}
# {'category': 'all_cases_with_log2_cna_data', 'name': 'Samples with log2 copy-number data', 'description': 'Samples with log2 copy-number data (89 samples)', 'sampleListId': 'acc_tcga_pan_can_atlas_2018_log2CNA', 'studyId': 'acc_tcga_pan_can_atlas_2018'}
# {'category': 'all_cases_with_rppa_data', 'name': 'Samples with protein data (RPPA)', 'description': 'Samples with protein data (RPPA) (45 samples)', 'sampleListId': 'acc_tcga_pan_can_atlas_2018_rppa', 'studyId': 'acc_tcga_pan_can_atlas_2018'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (91 samples)', 'sampleListId': 'acc_tcga_pan_can_atlas_2018_sequenced', 'studyId': 'acc_tcga_pan_can_atlas_2018'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'Samples with SV data', 'sampleListId': 'acc_tcga_pan_can_atlas_2018_sv', 'studyId': 'acc_tcga_pan_can_atlas_2018'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (25040 samples)', 'sampleListId': 'msk_chord_2024_all', 'studyId': 'msk_chord_2024'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (25034 samples)', 'sampleListId': 'msk_chord_2024_cna', 'studyId': 'msk_chord_2024'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (25040 samples)', 'sampleListId': 'msk_chord_2024_cnaseq', 'studyId': 'msk_chord_2024'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (25040 samples)', 'sampleListId': 'msk_chord_2024_sequenced', 'studyId': 'msk_chord_2024'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples with SV data (25040 samples)', 'sampleListId': 'msk_chord_2024_sv', 'studyId': 'msk_chord_2024'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (786 samples)', 'sampleListId': 'pancan_mappyacts_2022_all', 'studyId': 'pancan_mappyacts_2022'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (267 samples)', 'sampleListId': 'pancan_mappyacts_2022_cna', 'studyId': 'pancan_mappyacts_2022'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (267 samples)', 'sampleListId': 'pancan_mappyacts_2022_cnaseq', 'studyId': 'pancan_mappyacts_2022'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (674 samples)', 'sampleListId': 'pancan_mappyacts_2022_sequenced', 'studyId': 'pancan_mappyacts_2022'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples with SV data (56 samples)', 'sampleListId': 'pancan_mappyacts_2022_sv', 'studyId': 'pancan_mappyacts_2022'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (25775 samples)', 'sampleListId': 'msk_met_2021_all', 'studyId': 'msk_met_2021'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (25775 samples)', 'sampleListId': 'msk_met_2021_cna', 'studyId': 'msk_met_2021'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (25775 samples)', 'sampleListId': 'msk_met_2021_cnaseq', 'studyId': 'msk_met_2021'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (25775 samples)', 'sampleListId': 'msk_met_2021_sequenced', 'studyId': 'msk_met_2021'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples (25775 samples)', 'sampleListId': 'msk_met_2021_sv', 'studyId': 'msk_met_2021'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (2336 samples)', 'sampleListId': 'pdac_msk_2024_all', 'studyId': 'pdac_msk_2024'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (2336 samples)', 'sampleListId': 'pdac_msk_2024_cna', 'studyId': 'pdac_msk_2024'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (2336 samples)', 'sampleListId': 'pdac_msk_2024_cnaseq', 'studyId': 'pdac_msk_2024'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (2336 samples)', 'sampleListId': 'pdac_msk_2024_sequenced', 'studyId': 'pdac_msk_2024'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples with SV data (2336 samples)', 'sampleListId': 'pdac_msk_2024_sv', 'studyId': 'pdac_msk_2024'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (48 samples)', 'sampleListId': 'rectal_radiation_msk_2024_all', 'studyId': 'rectal_radiation_msk_2024'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (48 samples)', 'sampleListId': 'rectal_radiation_msk_2024_cna', 'studyId': 'rectal_radiation_msk_2024'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (48 samples)', 'sampleListId': 'rectal_radiation_msk_2024_cnaseq', 'studyId': 'rectal_radiation_msk_2024'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (48 samples)', 'sampleListId': 'rectal_radiation_msk_2024_sequenced', 'studyId': 'rectal_radiation_msk_2024'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples with SV data (48 samples)', 'sampleListId': 'rectal_radiation_msk_2024_sv', 'studyId': 'rectal_radiation_msk_2024'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (18 samples)', 'sampleListId': 'normal_skin_fibroblast_2024_all', 'studyId': 'normal_skin_fibroblast_2024'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (18 samples)', 'sampleListId': 'normal_skin_fibroblast_2024_sequenced', 'studyId': 'normal_skin_fibroblast_2024'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (136 samples)', 'sampleListId': 'normal_skin_keratinocytes_2024_all', 'studyId': 'normal_skin_keratinocytes_2024'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (136 samples)', 'sampleListId': 'normal_skin_keratinocytes_2024_sequenced', 'studyId': 'normal_skin_keratinocytes_2024'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (3879 samples)', 'sampleListId': 'breast_msk_2025_all', 'studyId': 'breast_msk_2025'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (3879 samples)', 'sampleListId': 'breast_msk_2025_cna', 'studyId': 'breast_msk_2025'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (3879 samples)', 'sampleListId': 'breast_msk_2025_cnaseq', 'studyId': 'breast_msk_2025'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (3879 samples)', 'sampleListId': 'breast_msk_2025_sequenced', 'studyId': 'breast_msk_2025'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples with SV data (3879 samples)', 'sampleListId': 'breast_msk_2025_sv', 'studyId': 'breast_msk_2025'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (184 samples)', 'sampleListId': 'blca_msk_2024_all', 'studyId': 'blca_msk_2024'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (184 samples)', 'sampleListId': 'blca_msk_2024_cna', 'studyId': 'blca_msk_2024'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (184 samples)', 'sampleListId': 'blca_msk_2024_cnaseq', 'studyId': 'blca_msk_2024'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (184 samples)', 'sampleListId': 'blca_msk_2024_sequenced', 'studyId': 'blca_msk_2024'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with mutation data', 'description': 'Samples with SV data (184 samples)', 'sampleListId': 'blca_msk_2024_sv', 'studyId': 'blca_msk_2024'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (153 samples)', 'sampleListId': 'normal_skin_melanocytes_2024_all', 'studyId': 'normal_skin_melanocytes_2024'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (153 samples)', 'sampleListId': 'normal_skin_melanocytes_2024_sequenced', 'studyId': 'normal_skin_melanocytes_2024'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (190 samples)', 'sampleListId': 'thyroid_gatci_2024_all', 'studyId': 'thyroid_gatci_2024'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (190 samples)', 'sampleListId': 'thyroid_gatci_2024_cna', 'studyId': 'thyroid_gatci_2024'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (190 samples)', 'sampleListId': 'thyroid_gatci_2024_cnaseq', 'studyId': 'thyroid_gatci_2024'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (190 samples)', 'sampleListId': 'thyroid_gatci_2024_sequenced', 'studyId': 'thyroid_gatci_2024'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (107 samples)', 'sampleListId': 'braf_msk_archer_2024_all', 'studyId': 'braf_msk_archer_2024'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples with SV data (107 samples)', 'sampleListId': 'braf_msk_archer_2024_sv', 'studyId': 'braf_msk_archer_2024'}
# {'category': 'all_cases_in_study', 'name': 'All samples', 'description': 'All samples (105 samples)', 'sampleListId': 'braf_msk_impact_2024_all', 'studyId': 'braf_msk_impact_2024'}
# {'category': 'all_cases_with_cna_data', 'name': 'Samples with CNA data', 'description': 'Samples with CNA data (105 samples)', 'sampleListId': 'braf_msk_impact_2024_cna', 'studyId': 'braf_msk_impact_2024'}
# {'category': 'all_cases_with_mutation_and_cna_data', 'name': 'Samples with mutation and CNA data', 'description': 'Samples with mutation and CNA data (105 samples)', 'sampleListId': 'braf_msk_impact_2024_cnaseq', 'studyId': 'braf_msk_impact_2024'}
# {'category': 'all_cases_with_mutation_data', 'name': 'Samples with mutation data', 'description': 'Samples with mutation data (105 samples)', 'sampleListId': 'braf_msk_impact_2024_sequenced', 'studyId': 'braf_msk_impact_2024'}
# {'category': 'all_cases_with_sv_data', 'name': 'Samples with SV data', 'description': 'All samples with SV data (105 samples)', 'sampleListId': 'braf_msk_impact_2024_sv', 'studyId': 'braf_msk_impact_2024'}
# {'category': 'all_cases_in_study', 'name': 'All Tumors', 'description': 'All tumor samples', 'sampleListId': 'ovary_geomx_gray_foundation_2024_all', 'studyId': 'ovary_geomx_gray_foundation_2024'}

# %%
def get_study_sample_lists(study_id):
    """Fetch study list IDs for a specific study"""
    url = f"{BASE_URL}/studies/{study_id}/sample-lists"
    response = requests.get(url, headers=HEADERS)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

# Example Usage
study_id = "pptc_2019" 
study_sample_lists = get_study_sample_lists(study_id)

# not working, says there are no sample lists found)
# if mutations:
#     print("✅ Study sample lists:")
#     for sample_lists in study_sample_lists:  # Print first 10 results
#         print(sample_lists)
# else:
#     print("❌ No sample lists found.")

study_sample_lists
# Out:
# [{'category': 'all_cases_with_mrna_rnaseq_data',
#   'name': 'Samples with mRNA data (RNA Seq)',
#   'description': 'Samples with mRNA expression data (244 samples)',
#   'sampleListId': 'pptc_2019_rna_seq_mrna',
#   'studyId': 'pptc_2019'},
#  {'category': 'all_cases_in_study',
#   'name': 'All samples',
#   'description': 'All samples (261 samples)',
#   'sampleListId': 'pptc_2019_all',
#   'studyId': 'pptc_2019'},
#  {'category': 'all_cases_with_cna_data',
#   'name': 'Samples with CNA data',
#   'description': 'Samples with CNA data (252 samples)',
#   'sampleListId': 'pptc_2019_cna',
#   'studyId': 'pptc_2019'},
#  {'category': 'all_cases_with_mutation_and_cna_data',
#   'name': 'Samples with mutation and CNA data',
#   'description': 'Samples with mutation and CNA data (232 samples)',
#   'sampleListId': 'pptc_2019_cnaseq',
#   'studyId': 'pptc_2019'},
#  {'category': 'all_cases_with_mutation_and_cna_and_mrna_data',
#   'name': 'Complete samples',
#   'description': 'Samples with mutation, CNA and expression data (222 samples)',
#   'sampleListId': 'pptc_2019_3way_complete',
#   'studyId': 'pptc_2019'},
#  {'category': 'all_cases_with_mutation_data',
#   'name': 'Samples with mutation data',
#   'description': 'Samples with mutation data (261 samples)',
#   'sampleListId': 'pptc_2019_sequenced',
#   'studyId': 'pptc_2019'},
#  {'category': 'all_cases_with_sv_data',
#   'name': 'Samples with SV data',
#   'description': 'All samples (244 samples)',
#   'sampleListId': 'pptc_2019_sv',
#   'studyId': 'pptc_2019'}]

# %%
import requests

BASE_URL = "https://www.cbioportal.org/api"
HEADERS = {"Content-Type": "application/json"}

def get_mutations(molecular_profile_id, sample_list_id):
    """Fetch mutation data for a specific molecular profile using a sample list ID"""
    url = f"{BASE_URL}/molecular-profiles/{molecular_profile_id}/mutations/fetch"
    payload = {"sampleListId": sample_list_id}  # Include required parameter in the payload
    response = requests.post(url, headers=HEADERS, json=payload)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

# Example Usage
molecular_profile_id = "pptc_2019_mutations" 
sample_list_id = "pptc_2019_mutations"  # Replace with a valid sample list ID
mutations = get_mutations(molecular_profile_id, sample_list_id)

if mutations:
    print("✅ Mutation Data:")
    for mutation in mutations:
        print(mutation)
else:
    print("❌ No mutation data found.")
# Out:
# ❌ No mutation data found.

# %%
import requests

BASE_URL = "https://www.cbioportal.org/api"
HEADERS = {"Content-Type": "application/json"}

def get_sample_ids(study_id):
    """Fetch case data for the study and extract sample IDs."""
    url = f"{BASE_URL}/studies/{study_id}/cases"
    response = requests.get(url, headers=HEADERS)
    
    if response.status_code == 200:
        cases = response.json()
        # Extract the sampleId from each case
        sample_ids = [case.get("sampleId") for case in cases if case.get("sampleId")]
        return sample_ids
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

study_id = "pptc_2019"
sample_ids = get_sample_ids(study_id)

if sample_ids:
    print("Sample IDs:")
    for sid in sample_ids:
        print(sid)
else:
    print("No sample IDs found.")
# Out:
# Error 404: {"timestamp":1742314035276,"status":404,"error":"Not Found","path":"/api/studies/pptc_2019/cases"}
# No sample IDs found.

# %%
import requests

BASE_URL = "https://www.cbioportal.org/api"
HEADERS = {"Content-Type": "application/json"}

def get_case_lists(study_id):
    """Fetch case lists for a specific study."""
    url = f"{BASE_URL}/studies/{study_id}/case-lists"
    response = requests.get(url, headers=HEADERS)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

study_id = "pptc_2019"
case_lists = get_case_lists(study_id)

if case_lists:
    # Inspect all case lists
    for cl in case_lists:
        print(f"Case List ID: {cl.get('caseListId')}")
        sample_ids = cl.get("sampleIds", [])
        print("Sample IDs:")
        for sid in sample_ids:
            print(sid)
        print("-" * 40)
else:
    print("No case lists found.")
# Out:
# Error 404: {"timestamp":1742313215625,"status":404,"error":"Not Found","path":"/api/studies/pptc_2019/case-lists"}
# No case lists found.

# %%
import requests

BASE_URL = "https://www.cbioportal.org/api"
HEADERS = {"Content-Type": "application/json"}

def get_molecular_profile(molecular_profile_id):
    """Fetch molecular profile details including sample IDs."""
    url = f"{BASE_URL}/molecular-profiles/{molecular_profile_id}"
    response = requests.get(url, headers=HEADERS)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

molecular_profile_id = "pptc_2019_mutations"
profile = get_molecular_profile(molecular_profile_id)

if profile and "sampleIds" in profile:
    sample_ids = profile["sampleIds"]
    print("✅ Sample IDs:")
    for sid in sample_ids:
        print(sid)
else:
    print("❌ No sample IDs found.")
# Out:
# ❌ No sample IDs found.
