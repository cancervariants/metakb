# %%
import pandas as pd
import requests

# %% [markdown]
# ## Grabbing Mutational Data from cBioPortal Swagger API
# cBioPortal has a bunch of weird API access points. We were able to identify a SWAGGER API end point and play around with some of the listed examples to identify a way to access mutational data. Actually identifying what endpoints to use to grab our interested data is proving to be tricky though. I'm hoping that if we can grab all mutations (variants), therapeutics, and diseases (outcomes too?) from a sample set, we can use the unique sample / patient identifiers to link everything back together and create a "Study" node in MetaKB v2.

# %% [markdown]
# ### Grab Study Sample Lists and Identifiers

# %%
r = requests.get('https://www.cbioportal.org/api/sample-lists?projection=DETAILED&pageSize=10000000&pageNumber=0&direction=ASC')
print(r.status_code)
response = r.json()
# Out:
# 200

# %%
data = []
for record in response:
    row = {
        'category': record.get('category',None),
        'name': record.get('name',None),
        'sampleListId': record.get('sampleListId',None),
        'studyId': record.get('studyId',None),
        'sampleCount': record.get('sampleCount',None),
        'sampleIds': record.get('sampleIds',None)
    }
    data.append(row)

cbio_studies = pd.DataFrame(data)
cbio_studies
# Out:
#                                   category  \
# 0                       all_cases_in_study
# 1                  all_cases_with_cna_data
# 2     all_cases_with_mutation_and_cna_data
# 3             all_cases_with_mutation_data
# 4                   all_cases_with_sv_data
# ...                                    ...
# 2543          all_cases_with_mutation_data
# 2544                    all_cases_in_study
# 2545       all_cases_with_mrna_rnaseq_data
# 2546          all_cases_with_mutation_data
# 2547                all_cases_with_sv_data
#
#                                      name                  sampleListId  \
# 0                             All samples         pancreas_msk_2024_all
# 1                   Samples with CNA data         pancreas_msk_2024_cna
# 2      Samples with mutation and CNA data      pancreas_msk_2024_cnaseq
# 3              Samples with mutation data   pancreas_msk_2024_sequenced
# 4                    Samples with SV data          pancreas_msk_2024_sv
# ...                                   ...                           ...
# 2543           Samples with mutation data  thyroid_gatci_2024_sequenced
# 2544                          All samples              mbn_sfu_2023_all
# 2545  Samples with mRNA data (RNA Seq V2)  mbn_sfu_2023_rna_seq_v2_mrna
# 2546           Samples with mutation data        mbn_sfu_2023_sequenced
# 2547                 Samples with SV data               mbn_sfu_2023_sv
#
#                  studyId  sampleCount  \
# 0      pancreas_msk_2024          395
# 1      pancreas_msk_2024          395
# 2      pancreas_msk_2024          395
# 3      pancreas_msk_2024          395
# 4      pancreas_msk_2024          395
# ...                  ...          ...
# 2543  thyroid_gatci_2024          190
# 2544        mbn_sfu_2023          297
# 2545        mbn_sfu_2023          297
# 2546        mbn_sfu_2023          297
# 2547        mbn_sfu_2023          297
#
#                                               sampleIds
# 0     [P-0000142-T01-IM3, P-0002230-T01-IM3, P-00027...
# 1     [P-0000142-T01-IM3, P-0002230-T01-IM3, P-00027...
# 2     [P-0000142-T01-IM3, P-0002230-T01-IM3, P-00027...
# 3     [P-0000142-T01-IM3, P-0002230-T01-IM3, P-00027...
# 4     [P-0000142-T01-IM3, P-0002230-T01-IM3, P-00027...
# ...                                                 ...
# 2543  [ANPT0001P, ANPT0002P, ANPT0003P, ANPT0004P, A...
# 2544  [BLGSP-71-06-00001-01A, BLGSP-71-06-00002-01C,...
# 2545  [BLGSP-71-06-00001-01A, BLGSP-71-06-00002-01C,...
# 2546  [BLGSP-71-06-00001-01A, BLGSP-71-06-00002-01C,...
# 2547  [BLGSP-71-06-00001-01A, BLGSP-71-06-00002-01C,...
#
# [2548 rows x 6 columns]

# %% [markdown]
# The `studyId` and `sampleListId` columns can be used to grab mutations, other data sets in the following API calls.
#
# These are just a few of the endpoints that I have looked at, there are others to explore at the swaggerui: `https://www.cbioportal.org/api/swagger-ui/index.html#/`

# %%
cbio_studies[cbio_studies['studyId'].str.contains('pptc_2019')]
# Out:
#                                           category  \
# 593                all_cases_with_mrna_rnaseq_data
# 594                             all_cases_in_study
# 595                        all_cases_with_cna_data
# 596           all_cases_with_mutation_and_cna_data
# 597  all_cases_with_mutation_and_cna_and_mrna_data
# 598                   all_cases_with_mutation_data
# 599                         all_cases_with_sv_data
#
#                                    name             sampleListId    studyId  \
# 593    Samples with mRNA data (RNA Seq)   pptc_2019_rna_seq_mrna  pptc_2019
# 594                         All samples            pptc_2019_all  pptc_2019
# 595               Samples with CNA data            pptc_2019_cna  pptc_2019
# 596  Samples with mutation and CNA data         pptc_2019_cnaseq  pptc_2019
# 597                    Complete samples  pptc_2019_3way_complete  pptc_2019
# 598          Samples with mutation data      pptc_2019_sequenced  pptc_2019
# 599                Samples with SV data             pptc_2019_sv  pptc_2019
#
#      sampleCount                                          sampleIds
# 593          244  [ALL-03, MLL-1, MLL-14, MLL-2, MLL-3, MLL-5, M...
# 594          261  [ALL-03, MLL-1, MLL-14, MLL-2, MLL-3, MLL-5, M...
# 595          252  [ALL-03, MLL-1, MLL-14, MLL-2, MLL-3, MLL-5, M...
# 596          232  [ALL-03, MLL-1, MLL-14, MLL-2, MLL-3, MLL-5, M...
# 597          222  [ALL-03, MLL-1, MLL-14, MLL-2, MLL-3, MLL-5, M...
# 598          261  [ALL-03, MLL-1, MLL-14, MLL-2, MLL-3, MLL-5, M...
# 599          244  [ALL-03, MLL-1, MLL-14, MLL-2, MLL-3, MLL-5, M...

# %% [markdown]
# I can't find any solid documentation on this, but it seems like for some of the end points to work properly, you just use the parent studyId and append whatever the API is looking for to it (e.g. `pptc_2019` becomes `pptc_2019_mutations` if you are using the mutations endpoint)

# %% [markdown]
# ### Grab Mutations
# Mutation data from each sample set seems pretty useful for identifying variants. Let's grab this and create a dataframe that we can hopefully link later on using patientIDs.

# %%
study_name = 'pptc_2019'
r = requests.get(f'https://www.cbioportal.org/api/molecular-profiles/{study_name}_mutations/mutations?sampleListId={study_name}_all&projection=SUMMARY&pageSize=10000000&pageNumber=0&direction=ASC')
response = r.json()

# %%
data = []
for record in response:
    row = {
        'uniqueSampleKey': record.get('uniqueSampleKey',None),
        'uniquePatientKey': record.get('uniquePatientKey',None),
        'molecularProfileId': record.get('molecularProfileId',None),
        'sampleId': record.get('sampleId',None),
        'patientId': record.get('patientId',None),
        'startPosition': record.get('startPosition',None),
        'endPosition': record.get('endPosition',None),
        'ncbiBuild': record.get('ncbiBuild',None),
        'referenceAllele': record.get('referenceAllele',None),
        'variantAllele': record.get('variantAllele',None),
        'mutationType': record.get('mutationType',None),
        'proteinChange': record.get('proteinChange',None)
    }
    data.append(row)

df = pd.DataFrame(data)
df
# Out:
#                             uniqueSampleKey      uniquePatientKey  \
# 0                    QUxMLTAzOnBwdGNfMjAxOQ  UDAwMDI6cHB0Y18yMDE5
# 1                    QUxMLTAzOnBwdGNfMjAxOQ  UDAwMDI6cHB0Y18yMDE5
# 2                    QUxMLTAzOnBwdGNfMjAxOQ  UDAwMDI6cHB0Y18yMDE5
# 3                    QUxMLTAzOnBwdGNfMjAxOQ  UDAwMDI6cHB0Y18yMDE5
# 4                    QUxMLTAzOnBwdGNfMjAxOQ  UDAwMDI6cHB0Y18yMDE5
# ...                                     ...                   ...
# 42571  TkNILVdULTgtUzEzLTM3MDA6cHB0Y18yMDE5  UDAxOTE6cHB0Y18yMDE5
# 42572  TkNILVdULTgtUzEzLTM3MDA6cHB0Y18yMDE5  UDAxOTE6cHB0Y18yMDE5
# 42573  TkNILVdULTgtUzEzLTM3MDA6cHB0Y18yMDE5  UDAxOTE6cHB0Y18yMDE5
# 42574  TkNILVdULTgtUzEzLTM3MDA6cHB0Y18yMDE5  UDAxOTE6cHB0Y18yMDE5
# 42575  TkNILVdULTgtUzEzLTM3MDA6cHB0Y18yMDE5  UDAxOTE6cHB0Y18yMDE5
#
#         molecularProfileId           sampleId patientId  startPosition  \
# 0      pptc_2019_mutations             ALL-03     P0002       20711345
# 1      pptc_2019_mutations             ALL-03     P0002      151545824
# 2      pptc_2019_mutations             ALL-03     P0002       56142751
# 3      pptc_2019_mutations             ALL-03     P0002       28377812
# 4      pptc_2019_mutations             ALL-03     P0002       35403920
# ...                    ...                ...       ...            ...
# 42571  pptc_2019_mutations  NCH-WT-8-S13-3700     P0191      205273009
# 42572  pptc_2019_mutations  NCH-WT-8-S13-3700     P0191       41967015
# 42573  pptc_2019_mutations  NCH-WT-8-S13-3700     P0191       34942916
# 42574  pptc_2019_mutations  NCH-WT-8-S13-3700     P0191       19368846
# 42575  pptc_2019_mutations  NCH-WT-8-S13-3700     P0191       39185272
#
#        endPosition ncbiBuild referenceAllele variantAllele       mutationType  \
# 0         20711345    GRCh37               G             A  Missense_Mutation
# 1        151545824    GRCh37               G             A  Missense_Mutation
# 2         56142751    GRCh37               C             T  Missense_Mutation
# 3         28377812    GRCh37               A             T  Missense_Mutation
# 4         35403920    GRCh37               G             A  Missense_Mutation
# ...            ...       ...             ...           ...                ...
# 42571    205273009    GRCh37               G             A  Nonsense_Mutation
# 42572     41967015    GRCh37               G             A  Missense_Mutation
# 42573     34942916    GRCh37               A             G  Missense_Mutation
# 42574     19368846    GRCh37               T             G  Missense_Mutation
# 42575     39185272    GRCh37               A             T  Missense_Mutation
#
#       proteinChange
# 0             R132Q
# 1             R355Q
# 2             P276L
# 3            L4132Q
# 4            E1556K
# ...             ...
# 42571         Q486*
# 42572         E812K
# 42573         N301S
# 42574         Y330S
# 42575         T490S
#
# [42576 rows x 12 columns]

# %% [markdown]
# ### Get Clinical Attributes
# TODO: Figure out what this is and if it is useful

# %%
study_name = 'pptc_2019'
r = requests.get(f'https://www.cbioportal.org/api/studies/{study_name}/clinical-attributes?projection=DETAILED&pageSize=10000000&pageNumber=0&direction=ASC')
r.json()
# Out:
# [{'displayName': 'Age',
#   'description': 'Age',
#   'datatype': 'NUMBER',
#   'patientAttribute': True,
#   'priority': '1',
#   'clinicalAttributeId': 'AGE',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Cancer Subtype Curated',
#   'description': 'Cancer Subtype Curated',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '5',
#   'clinicalAttributeId': 'CANCER_SUBTYPE_CURATED',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Cancer Type',
#   'description': 'Cancer Type',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '1',
#   'clinicalAttributeId': 'CANCER_TYPE',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Cancer Type Detailed',
#   'description': 'Cancer Type Detailed',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '1',
#   'clinicalAttributeId': 'CANCER_TYPE_DETAILED',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'EXPRESSION',
#   'description': 'EXPRESSION',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '2',
#   'clinicalAttributeId': 'EXPRESSION',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Fraction Genome Altered',
#   'description': 'Fraction Genome Altered',
#   'datatype': 'NUMBER',
#   'patientAttribute': False,
#   'priority': '20',
#   'clinicalAttributeId': 'FRACTION_GENOME_ALTERED',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'HISTOPATHOLOGY',
#   'description': 'HISTOPATHOLOGY',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '3',
#   'clinicalAttributeId': 'HISTOPATHOLOGY',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Inferred Ethnicity',
#   'description': 'Inferred Ethnicity',
#   'datatype': 'STRING',
#   'patientAttribute': True,
#   'priority': '1',
#   'clinicalAttributeId': 'INFERRED_ETHNICITY',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Mutation Count',
#   'description': 'Mutation Count',
#   'datatype': 'NUMBER',
#   'patientAttribute': False,
#   'priority': '30',
#   'clinicalAttributeId': 'MUTATION_COUNT',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Note',
#   'description': 'Note.',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '2',
#   'clinicalAttributeId': 'NOTE',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Oncotree Code',
#   'description': 'Oncotree Code',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '1',
#   'clinicalAttributeId': 'ONCOTREE_CODE',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'PHASE',
#   'description': 'PHASE',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '4',
#   'clinicalAttributeId': 'PHASE',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Reported Ethnicity',
#   'description': 'Reported Ethnicity',
#   'datatype': 'STRING',
#   'patientAttribute': True,
#   'priority': '1',
#   'clinicalAttributeId': 'REPORTED_ETHNICITY',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Number of Samples Per Patient',
#   'description': 'Number of Samples Per Patient',
#   'datatype': 'STRING',
#   'patientAttribute': True,
#   'priority': '1',
#   'clinicalAttributeId': 'SAMPLE_COUNT',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Site of Sample',
#   'description': 'Sample Site',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '4',
#   'clinicalAttributeId': 'SAMPLE_SITE',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Sex',
#   'description': 'Sex',
#   'datatype': 'STRING',
#   'patientAttribute': True,
#   'priority': '1',
#   'clinicalAttributeId': 'SEX',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'SPECIMEN_SITE',
#   'description': 'SPECIMEN_SITE',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '4',
#   'clinicalAttributeId': 'SITE_OF_SPECIMEN',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'TMB (nonsynonymous)',
#   'description': 'TMB (nonsynonymous)',
#   'datatype': 'NUMBER',
#   'patientAttribute': False,
#   'priority': '1',
#   'clinicalAttributeId': 'TMB_NONSYNONYMOUS',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment 17-DMAG',
#   'description': 'Treatment 17-DMAG',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_17-DMAG',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment 19D12',
#   'description': 'Treatment 19D12',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_19D12',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment ABRAXANE',
#   'description': 'Treatment ABRAXANE',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_ABRAXANE',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment ABT-199',
#   'description': 'Treatment ABT-199',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_ABT-199',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment ABT-263',
#   'description': 'Treatment ABT-263',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_ABT-263',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment ACTINOMYCIN D',
#   'description': 'Treatment ACTINOMYCIN D',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_ACTINOMYCIN D',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment APLIDIN',
#   'description': 'Treatment APLIDIN',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_APLIDIN',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment AZD-2171',
#   'description': 'Treatment AZD-2171',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_AZD-2171',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment AZD-6244',
#   'description': 'Treatment AZD-6244',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_AZD-6244',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment AZD1480',
#   'description': 'Treatment AZD1480',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_AZD1480',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment AZD8055',
#   'description': 'Treatment AZD8055',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_AZD8055',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment BAL101553',
#   'description': 'Treatment BAL101553',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_BAL101553',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment BI6727 (VOLASERTIB)',
#   'description': 'Treatment BI6727 (VOLASERTIB)',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_BI6727 (VOLASERTIB)',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment BMN-673',
#   'description': 'Treatment BMN-673',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_BMN-673',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment BMS-354825',
#   'description': 'Treatment BMS-354825',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_BMS-354825',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment BMS-754807',
#   'description': 'Treatment BMS-754807',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_BMS-754807',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment BORTEZOMIB',
#   'description': 'Treatment BORTEZOMIB',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_BORTEZOMIB',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment CABOZANTINIB (XL-148)',
#   'description': 'Treatment CABOZANTINIB (XL-148)',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_CABOZANTINIB (XL-148)',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment CBL0137',
#   'description': 'Treatment CBL0137',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_CBL0137',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment CDX-011 (GLEMBATUMUMAB)',
#   'description': 'Treatment CDX-011 (GLEMBATUMUMAB)',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_CDX-011 (GLEMBATUMUMAB)',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment CGC(PG)-11047',
#   'description': 'Treatment CGC(PG)-11047',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_CGC(PG)-11047',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment CISPLATIN',
#   'description': 'Treatment CISPLATIN',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_CISPLATIN',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment CLORETAZINE',
#   'description': 'Treatment CLORETAZINE',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_CLORETAZINE',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment CPX351',
#   'description': 'Treatment CPX351',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_CPX351',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment CX-5461 (POL1)',
#   'description': 'Treatment CX-5461 (POL1)',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_CX-5461 (POL1)',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment CYCLOPHOSPHAMIDE',
#   'description': 'Treatment CYCLOPHOSPHAMIDE',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_CYCLOPHOSPHAMIDE',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment CYTARABINE',
#   'description': 'Treatment CYTARABINE',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_CYTARABINE',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment E7438/EPZ6438',
#   'description': 'Treatment E7438/EPZ6438',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_E7438/EPZ6438',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment EC1456',
#   'description': 'Treatment EC1456',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_EC1456',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment ERIBULIN',
#   'description': 'Treatment ERIBULIN',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_ERIBULIN',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment FENRETINIDE',
#   'description': 'Treatment FENRETINIDE',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_FENRETINIDE',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment GENZ-644282',
#   'description': 'Treatment GENZ-644282',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_GENZ-644282',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment GS-9820',
#   'description': 'Treatment GS-9820',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_GS-9820',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment GSK690693',
#   'description': 'Treatment GSK690693',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_GSK690693',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment GSK923295A',
#   'description': 'Treatment GSK923295A',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_GSK923295A',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment HGS-ETR1',
#   'description': 'Treatment HGS-ETR1',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_HGS-ETR1',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment IMC-A12',
#   'description': 'Treatment IMC-A12',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_IMC-A12',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment INK128-1110-028',
#   'description': 'Treatment INK128-1110-028',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_INK128-1110-028',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment JNJ26481585',
#   'description': 'Treatment JNJ26481585',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_JNJ26481585',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment JNJ26854165',
#   'description': 'Treatment JNJ26854165',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_JNJ26854165',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment KPT-330',
#   'description': 'Treatment KPT-330',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_KPT-330',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment LAPATINIB',
#   'description': 'Treatment LAPATINIB',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_LAPATINIB',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment LENOLIDAMIDE',
#   'description': 'Treatment LENOLIDAMIDE',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_LENOLIDAMIDE',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment LY 2606368',
#   'description': 'Treatment LY 2606368',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_LY 2606368',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment MK-2206',
#   'description': 'Treatment MK-2206',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_MK-2206',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment MK-8242',
#   'description': 'Treatment MK-8242',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_MK-8242',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment MLN4924',
#   'description': 'Treatment MLN4924',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_MLN4924',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment MLN8237',
#   'description': 'Treatment MLN8237',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_MLN8237',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment MM-141',
#   'description': 'Treatment MM-141',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_MM-141',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment NSC060043',
#   'description': 'Treatment NSC060043',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_NSC060043',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment NSC750854',
#   'description': 'Treatment NSC750854',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_NSC750854',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment PCI-32765',
#   'description': 'Treatment PCI-32765',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_PCI-32765',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment PF-03084014',
#   'description': 'Treatment PF-03084014',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_PF-03084014',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment PIXANTRONE',
#   'description': 'Treatment PIXANTRONE',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_PIXANTRONE',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment PR-104',
#   'description': 'Treatment PR-104',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_PR-104',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment RAPAMYCIN',
#   'description': 'Treatment RAPAMYCIN',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_RAPAMYCIN',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment RG7112',
#   'description': 'Treatment RG7112',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_RG7112',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment RO4929097',
#   'description': 'Treatment RO4929097',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_RO4929097',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment RUXOLITINIB',
#   'description': 'Treatment RUXOLITINIB',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_RUXOLITINIB',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment SAHA',
#   'description': 'Treatment SAHA',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_SAHA',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment SAR3419',
#   'description': 'Treatment SAR3419',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_SAR3419',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment SB-715992',
#   'description': 'Treatment SB-715992',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_SB-715992',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment SCH 727965',
#   'description': 'Treatment SCH 727965',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_SCH 727965',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment SGI-1776',
#   'description': 'Treatment SGI-1776',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_SGI-1776',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment SGN-CD19A',
#   'description': 'Treatment SGN-CD19A',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_SGN-CD19A',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment SORAFENIB',
#   'description': 'Treatment SORAFENIB',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_SORAFENIB',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment STA9090 (GANETESPIB)',
#   'description': 'Treatment STA9090 (GANETESPIB)',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_STA9090 (GANETESPIB)',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment STF-118804',
#   'description': 'Treatment STF-118804',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_STF-118804',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment SU11248',
#   'description': 'Treatment SU11248',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_SU11248',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment SVV-001',
#   'description': 'Treatment SVV-001',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_SVV-001',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment TAK-701',
#   'description': 'Treatment TAK-701',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_TAK-701',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment TB-403',
#   'description': 'Treatment TB-403',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_TB-403',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment TL32711',
#   'description': 'Treatment TL32711',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_TL32711',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment TOPOTECAN',
#   'description': 'Treatment TOPOTECAN',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_TOPOTECAN',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment TRISENOX(ATO)',
#   'description': 'Treatment TRISENOX(ATO)',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_TRISENOX(ATO)',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment VINCRISTINE',
#   'description': 'Treatment VINCRISTINE',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_VINCRISTINE',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment VS-4718',
#   'description': 'Treatment VS-4718',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_VS-4718',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment XL147',
#   'description': 'Treatment XL147',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_XL147',
#   'studyId': 'pptc_2019'},
#  {'displayName': 'Treatment XL765',
#   'description': 'Treatment XL765',
#   'datatype': 'STRING',
#   'patientAttribute': False,
#   'priority': '0',
#   'clinicalAttributeId': 'TX_XL765',
#   'studyId': 'pptc_2019'}]

# %% [markdown]
# ### Other Datasets
# TODO: Identify if any of the other desired datapoints (therapeutics, diseases, predicates, outcomes) exist on any of these endpoints. If not, figure out how to get them from cBioPortal (bc I definitely see them on the general data explorer)
